# %%
#Plot
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

#Data Packages
import math
import pandas as pd
import numpy as np
import datetime

#Progress bar
from tqdm import tqdm

#Counter
from collections import Counter
import collections

#Operation
import operator

#Natural Language Processing Packages
import re
import nltk

## Download Resources
nltk.download("vader_lexicon")
nltk.download("stopwords")
nltk.download("averaged_perceptron_tagger")
nltk.download("wordnet")
nltk.download("punkt")

from nltk.sentiment import SentimentAnalyzer
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.sentiment.util import *
from nltk import tokenize
from nltk.corpus import stopwords
from nltk.tag import PerceptronTagger
from nltk.data import find

## Machine Learning
import sklearn
import sklearn.metrics as metrics
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\shenti10\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\shenti10\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\shenti10\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\shenti10\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\wordnet.zip.
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\shenti10\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.

# %% [markdown]
# # Pre-defined word for sentiment analysis

# %% [markdown]
# Update Lexicon --> Add Polarity Score for Restaurant Specific Words

# %%
new_words = {
"excellent":3.99,
"amazing":3.981,
"awesome":3.98,
"best":3.98,
"wonderful":3.979,
"authentic":3.97,
"incredible":3.97,
"incredibly":3.97,
"popular":3.96,
"well-known":3.96,
"delicious":3.95,
"tasty":3.94,
"five-star":3.91,
"fanciest":3.89,
"finest":3.89,
"fast":3.88,
"phenomenal":3.88,
"exceptional":3.83,
"exceptionally":3.83,
"extrodinary":3.82,
"magnificent":3.82,
"famous":3.81,
"fantastic":3.8,
"splendid":3.7,
"yummy":3.7,
"flavorful":3.699,
"flavourful":3.699,
"delightful":3.69,
"decent":3.6,
"unique":3.6,
"flavored":3.5,
"fancy":3.5,
"quick":3.1,
"classic":3,
"fresh":3,
"fine":0.1,
"please":0,
"yeah":0,
"xoxo":0
}
sid = SentimentIntensityAnalyzer()
#Update new words with polarity score
sid.lexicon.update(new_words)

# %% [markdown]
# Contraction Dictionary

# %%
contractions = {
"ain't": "am not / are not",
"aren't": "are not / am not",
"can't": "cannot",
"can't've": "cannot have",
"'cause": "because",
"could've": "could have",
"couldn't": "could not",
"couldn't've": "could not have",
"didn't": "did not",
"doesn't": "does not",
"don't": "do not",
"hadn't": "had not",
"hadn't've": "had not have",
"hasn't": "has not",
"haven't": "have not",
"he'd": "he had / he would",
"he'd've": "he would have",
"he'll": "he shall / he will",
"he'll've": "he shall have / he will have",
"he's": "he has / he is",
"how'd": "how did",
"how'd'y": "how do you",
"how'll": "how will",
"how's": "how has / how is",
"i'd": "I had / I would",
"i'd've": "I would have",
"i'll": "I shall / I will",
"i'll've": "I shall have / I will have",
"i'm": "I am",
"i've": "I have",
"isn't": "is not",
"it'd": "it had / it would",
"it'd've": "it would have",
"it'll": "it shall / it will",
"it'll've": "it shall have / it will have",
"it's": "it has / it is",
"let's": "let us",
"ma'am": "madam",
"mayn't": "may not",
"might've": "might have",
"mightn't": "might not",
"mightn't've": "might not have",
"must've": "must have",
"mustn't": "must not",
"mustn't've": "must not have",
"needn't": "need not",
"needn't've": "need not have",
"o'clock": "of the clock",
"oughtn't": "ought not",
"oughtn't've": "ought not have",
"shan't": "shall not",
"sha'n't": "shall not",
"shan't've": "shall not have",
"she'd": "she had / she would",
"she'd've": "she would have",
"she'll": "she shall / she will",
"she'll've": "she shall have / she will have",
"she's": "she has / she is",
"should've": "should have",
"shouldn't": "should not",
"shouldn't've": "should not have",
"so've": "so have",
"so's": "so as / so is",
"that'd": "that would / that had",
"that'd've": "that would have",
"that's": "that has / that is",
"there'd": "there had / there would",
"there'd've": "there would have",
"there's": "there has / there is",
"they'd": "they had / they would",
"they'd've": "they would have",
"they'll": "they shall / they will",
"they'll've": "they shall have / they will have",
"they're": "they are",
"they've": "they have",
"to've": "to have",
"wasn't": "was not",
"we'd": "we had / we would",
"we'd've": "we would have",
"we'll": "we will",
"we'll've": "we will have",
"we're": "we are",
"we've": "we have",
"weren't": "were not",
"what'll": "what shall / what will",
"what'll've": "what shall have / what will have",
"what're": "what are",
"what's": "what has / what is",
"what've": "what have",
"when's": "when has / when is",
"when've": "when have",
"where'd": "where did",
"where's": "where has / where is",
"where've": "where have",
"who'll": "who shall / who will",
"who'll've": "who shall have / who will have",
"who's": "who has / who is",
"who've": "who have",
"why's": "why has / why is",
"why've": "why have",
"will've": "will have",
"won't": "will not",
"won't've": "will not have",
"would've": "would have",
"wouldn't": "would not",
"wouldn't've": "would not have",
"y'all": "you all",
"y'all'd": "you all would",
"y'all'd've": "you all would have",
"y'all're": "you all are",
"y'all've": "you all have",
"you'd": "you had / you would",
"you'd've": "you would have",
"you'll": "you shall / you will",
"you'll've": "you shall have / you will have",
"you're": "you are",
"you've": "you have",
"icecream ": "ice-cream",
"ice cream": "ice-cream",
"hotpot": "hot-pot",
"hot pot": "hot-pot",
"dimsum":"dim-sum",
"dim sum":"dim-sum",
"eggtart":"egg-tart",
"egg tart":"egg-tart"
}

# %%
merge_dict = {"icecream ": "ice-cream",
"ice cream": "ice-cream",
"hotpot": "hot pot",
"hot pot": "hot-pot",
"dimsum":"dim-sum",              
"dim sum":"dim-sum",
"eggtart":"egg-tart",
"egg tart":"egg-tart"
}

# %% [markdown]
# # Helper Functions

# %%
# Use vader to evaluate sentiment of reviews, vader here!
def evalSentences(sentences, to_df=False, columns=[]):
    #Instantiate an instance to access SentimentIntensityAnalyzer class
    pdlist = []
    if to_df:
        for sentence in tqdm(sentences):
            ss = sid.polarity_scores(sentence)
            pdlist.append([sentence]+[ss['compound']])
        reviewDf = pd.DataFrame(pdlist)
        reviewDf.columns = columns
        return reviewDf
    
    else:
        for sentence in tqdm(sentences):
            print(sentence)
            ss = sid.polarity_scores(sentence)
            for k in sorted(ss):
                print('{0}: {1}, '.format(k, ss[k]), end='')
            print()

# %%
def get_yelp_df(path = 'data/', filename = 'Export_CleanedReview.json', sampling=False, top_user_num=6100, top_item_num=4000):
    """
    Get the pandas dataframe
    Sampling only the top users/items by density 
    Implicit representation applies
    """
    with open(filename,'r') as f:
        data = f.readlines()
        data = list(map(json.loads, data))
    
    data = data[0]
    #Get all the data from the data
    df = pd.DataFrame(data)
    
    df.rename(columns={'stars': 'review_stars', 'text': 'review_text', 'cool': 'review_cool',
                       'funny': 'review_funny', 'useful': 'review_useful'}, inplace=True)

    df['business_num_id'] = df.business_id.astype('category').\
        cat.rename_categories(range(0, df.business_id.nunique()))
    df['business_num_id'] = df['business_num_id'].astype('int')

    df['user_num_id'] = df.user_id.astype('category').\
    cat.rename_categories(range(0, df.user_id.nunique()))
    df['user_num_id'] = df['user_num_id'].astype('int')

    df['timestamp'] = df['date'].apply(date_to_timestamp)

    if sampling:
        df = filter_yelp_df(df, top_user_num=top_user_num, top_item_num=top_item_num)
        # Refresh num id
        df['business_num_id'] = df.business_id.astype('category').\
        cat.rename_categories(range(0, df.business_id.nunique()))
        df['business_num_id'] = df['business_num_id'].astype('int')
        
        df['user_num_id'] = df.user_id.astype('category').\
        cat.rename_categories(range(0, df.user_id.nunique()))
        df['user_num_id'] = df['user_num_id'].astype('int')
        # drop_list = ['date','review_id','review_funny','review_cool','review_useful']
        # df = df.drop(drop_list, axis=1)
    df = df.reset_index(drop = True)
    return df 

def filter_yelp_df(df, top_user_num=6100, top_item_num=4000):
    #Getting the reviews where starts are above 3
    df_implicit = df[df['review_stars']>3]
    frequent_user_id = df_implicit['user_num_id'].value_counts().head(top_user_num).index.values
    frequent_item_id = df_implicit['business_num_id'].value_counts().head(top_item_num).index.values
    return df.loc[(df['user_num_id'].isin(frequent_user_id)) & (df['business_num_id'].isin(frequent_item_id))]

def date_to_timestamp(date):
    dt = datetime.datetime.strptime(date, '%Y-%m-%d')
    return time.mktime(dt.timetuple())

def df_to_sparse(df, row_name='userId', col_name='movieId', value_name='rating',
                 shape=None):
    rows = df[row_name]
    cols = df[col_name]
    if value_name is not None:
        values = df[value_name]
    else:
        values = [1]*len(rows)
    return csr_matrix((values, (rows, cols)), shape=shape)

# %%
# def get_business_review(business_num_id,df_Subset_Cols):
#     # Set the business ID below
#     #3464 Hotpot, 2159 Hand-pulled noodle, 3490 Pai Northern Thai
#     review_text = df.loc[df['business_num_id'] == business_num_id, 'review_text'].sum()
#     #review_text
# #     for word in tqdm(review_text.split()):
# #         if word.lower() in contractions:
# #             review_text = review_text.replace(word, contractions[word.lower()])
    
#     for word in contractions.keys():
#         review_text = review_text.lower().replace(word,contractions[word.lower()])
    
#     df_spe_item = df_Subset_Cols.loc[df_Subset_Cols['business_num_id'] == business_num_id]
#     for i in range(len(df_spe_item)):
#         for word in contractions.keys():
#             row = df_spe_item.review_text.iloc[i].lower().replace(word,contractions[word.lower()])
#             df_spe_item['review_text'].iloc[i] = row
            
#     return review_text, df_spe_item

# %%
def get_business_review(business_num_id,df_Subset_Cols):
    # Set the business ID below
    #3464 Hotpot, 2159 Hand-pulled noodle, 3490 Pai Northern Thai
    review_text = df.loc[df['business_num_id'] == business_num_id, 'review_text'].sum()
    
    for word in contractions.keys():
        review_text = review_text.replace(word,contractions[word.lower()])
    
    df_spe_item = df_Subset_Cols.loc[df_Subset_Cols['business_num_id'] == business_num_id]

    return review_text, df_spe_item

# %%
# Noun Phrase Extraction Support Functions
lemmatizer = nltk.WordNetLemmatizer()
stemmer = nltk.stem.porter.PorterStemmer()

# generator, generate leaves one by one
# Filter only on NP (The other two labels may not be useful)
def leaves(tree):
    """Finds NP (nounphrase) leaf nodes of a chunk tree."""
    for subtree in tree.subtrees(filter = lambda t: t.label()=='NP' or t.label()=='JJ' or t.label()=='RB'):
        yield subtree.leaves()

# stemming, lematizing, lower case...
def normalise(word):
    """Normalises words to lowercase and stems and lemmatizes it."""
    word = word.lower()
    #word = stemmer.stem(word)
    if word != 'was':
        word = lemmatizer.lemmatize(word)
    return word
        
# stop-words and length control
def acceptable_word(word):
    """Checks conditions for acceptable word: length, stopword."""
    special_non_stopwords = ['is','was','are','were'] # Kick out a few words from stopwords list
    final_stop_words = list([word for word in stopwords.words('english') if word not in special_non_stopwords])
    accepted = (bool(2 <= len(word) <= 40)
    and word.lower() not in final_stop_words)
    return accepted
        
# generator, create item once a time
def get_terms(tree):
    for leaf in leaves(tree):
        # Normalize word in 
        term = [normalise(w) for w,t in leaf if acceptable_word(w) ]
        # Phrase only
        if len(term)>1:
            yield term

# %%
# Flatten phrase lists to get tokens for analysis
def flatten(npTokenList):
    finalList =[]
    for phrase in npTokenList:
        token = ''
        for word in phrase:
            token += word + ' '
        finalList.append(token.rstrip())
    return finalList

# %% [markdown]
# grammar

# %%
# Version 2
grammar1 = r"""
    NBAR:
        {<RB|RBS>?<JJ|JJR|JJS>+<NN|NNS>+}
    NP:
        {<NBAR>}
        {<NBAR><IN><NBAR>}
"""

grammar2 = r"""
    NBAR:
        {<NN|NNS>+<VBZ|VBD><RB>?<JJ>+}
    NP:
        {<NBAR>}
"""

# %%
def get_keyphrase_list(review_text):
    tagger = PerceptronTagger()
    pos_tag = tagger.tag
    taggedToks = pos_tag([word.lower() for word in re.findall(r'[\w]+-[\w]+[-[\w]+]?|[\w]+|[.,!?;]', review_text)])

    # Create phrase tree
    chunker1 = nltk.RegexpParser(grammar1)
    tree1= chunker1.parse(taggedToks)
    chunker2 = nltk.RegexpParser(grammar2)
    tree2= chunker2.parse(taggedToks)

    # Traverse tree and get noun phrases
    npTokenList1 = [word for word in get_terms(tree1)]
    # npTokenList
    npTokenList2 = [word for word in get_terms(tree2)]
    # Combine np token list to one
    npTokenList_duplicate = npTokenList1 + npTokenList2
    npTokenList = []
    for i in tqdm(npTokenList_duplicate):
        if i not in npTokenList:
            npTokenList.append(i)
    
    
    Extracted_list1 = flatten(npTokenList1)
    Extracted_list2 = flatten(npTokenList2)
    #Extracted_list = flatten([word
    #                           for word
    #                           in get_terms(chunker.parse(pos_tag([word.lower()
    #                                                               for word in re.findall(r'\w+', review_text)])))])
    Extracted_list = Extracted_list1 + list(set(Extracted_list2) - set(Extracted_list1))
    return Extracted_list,npTokenList

# %%
def get_noun_list(npToken_List,stop_words):
    # create a list of NN from the Keyphrase list
    NN_List=[]
    
    for word in npToken_List:
        phrase = pos_tag(word)
        for term in phrase:
            if term[1]=='NN':
                NN_List.append(term[0])
    NN_List=list(dict.fromkeys(NN_List))
    
    # filter out the stop words
    NN_List= [x for x in NN_List if x not in stop_words]
    return NN_List

# %%
def get_score_from_freq(NN_List,review_text,df_spe_item):
    lemmatizer = nltk.WordNetLemmatizer()
    stop = set(stopwords.words('english'))
    # Get the frequency of the noun from the whole review, store in the dict_Counter
    dict_Counter = {}
    c = collections.Counter([normalise(word) for word in re.findall(r'[\w]+-[\w]+[-[\w]+]?|[\w]+|[.,!?;]', review_text) if word.lower() not in stop and len(word) > 2])
    for term in tqdm(NN_List):
        if term in c:
            dict_Counter[term] = dict(c)[term]

    
    # Get the binary frequency of the noun for each review. If the word in this review, then it is 1, otherwise is 0
    # store in the review_freq_counter
    # initialize review_freq_counter
    review_freq_counter = {}   
    for k in dict_Counter.keys():
        review_freq_counter[k] = 0
        
    for i in tqdm(range(len(df_business.review_text.values))):
        temp = lemmatizer.lemmatize(df_business.review_text.values[i]).lower()
        for key in merge_dict.keys():
            temp=temp.replace(key,merge_dict[key])
        temp_list = re.findall(r'[\w]+-[\w]+[-[\w]+]?|[\w]+|[.,!?;]',temp)
        for word in dict_Counter.keys():
            if word in temp_list:
                review_freq_counter[word] = review_freq_counter[word]+1 
                
    # normalized score by --> dict_Counter(total frequency) * review_freq_counter(binary review frequency)
    normalized_score = {}
    for k in dict_Counter.keys():
        normalized_score[k] = 0

    #construct the score by multiplying
    for word in dict_Counter.keys():
        #normalized_score[word] = dict_Counter[word] * review_freq_counter[word]
        normalized_score[word] = review_freq_counter[word]

    #sort it and store it in a list
    final_score_counter=[]
    for key, value in tqdm(sorted(normalized_score.items(), key=lambda item: item[1], reverse = True)):
        temp = [key,value]
        final_score_counter.append(temp)
    return final_score_counter

# %%
def get_keyphrase_contain_topk(top_word_list, k,Extracted_list):
    topk_freq_words = [x[0] for x in top_word_list[0:k]]
    keyphrase_list = []
    for key_word in Extracted_list:
        for freq_word in topk_freq_words:
            if freq_word in key_word:
                keyphrase_list.append(key_word)
    return list(dict.fromkeys(keyphrase_list))

# %%
def get_final_keyphrase(df_keyphrase, topk, top_word_list):
    res_dict = {}
    topk_freq_words = [x[0] for x in top_word_list[0:topk]]
    for word in topk_freq_words:
        for i in range(df_keyphrase.keyphrase_list.values.shape[0]):
            #deduplicate with excisting keyphrases
            if df_keyphrase["keyphrase_list"][i] not in list(res_dict.values()):
                if word in df_keyphrase["keyphrase_list"][i].split():
                    if word not in res_dict:
                        res_dict[word] = df_keyphrase["keyphrase_list"][i]
                    if word in res_dict:
                        if df_keyphrase["Vader"][i] > df_keyphrase[df_keyphrase["keyphrase_list"] == res_dict[word]].Vader.values[0]:
                            res_dict[word] = df_keyphrase["keyphrase_list"][i]
    
    for (key,val) in res_dict.items():
        #replace words
        val = val.replace("was", "is").replace("were","are").replace("also","").replace("still","").replace("actual","")
        #deduplicate
        res_dict[key] = ' '.join(list(dict.fromkeys(val.split())))
        
        # reorder to a list
#     res_list = []
#     for i in topk_freq_words:
#         res_list.append([i,res_dict[i]])
    return res_dict

# %% [markdown]
# # Load and Read Data
# ### load data

# %%
#reviewJsonToronto = "..\\data\\Export_TorontoData.json"
reviewJsonToronto = "..\\data\\Cleaned_Toronto_Reviews.json"

# %% [markdown]
# ### Read Data

# %%
df = get_yelp_df(path ='', filename=reviewJsonToronto, sampling= True)

# %% [markdown]
# # Main
# # Pre-setting for the variables
# set :
# - which business to use
# - stop_words
# - tagger and pos_tag declaration
# - Number of top nouns

# %%
stop_words_defined = ["place","restaurant","food", "amount","experience","side","size","location","quality" ,"taste"\
,"thing","order","bowl","night","day","flavour","spot","portion","dish","meal","good","drink","time","everything","get",'delivery','nice',"customer","one"]
tagger = PerceptronTagger()
pos_tag = tagger.tag
# how many nouns are we looking at
top_k = 3

# %% [markdown]
# ## For a single restaurant

# %%
business_num_id = 540

# %%
# get whole review text and the dataframe for this item
review_text, df_business= get_business_review(business_num_id,df)
# get all keyphrases and npTokenList(keyphrases before flatten --> partitioned keyphrase)
Extracted_list,npTokenList = get_keyphrase_list(review_text)
# get a noun list
Noun_List = get_noun_list(npTokenList,stop_words_defined)
# get a noun and it's score(dict_Counter(total frequency) * review_freq_counter(binary review frequency)), store in list
top_noun_with_score = get_score_from_freq(Noun_List,review_text,df_business)
# keyphrases that contrain the top nouns
keyphrase_list = get_keyphrase_contain_topk(top_noun_with_score,top_k ,Extracted_list)
# get dataframe for the keyphrases with vader score
df_keyphrase = evalSentences(keyphrase_list, to_df=True,columns = ['keyphrase_list', 'Vader'])
# get final keyphrases(one for each noun)
keyphrase_final = get_final_keyphrase(df_keyphrase,3,top_noun_with_score)
keyphrase_final
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 553/553 [00:00<00:00, 184419.98it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 201/201 [00:00<00:00, 33529.08it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 72/72 [00:00<00:00, 2881.58it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 200/200 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 72/72 [00:00<00:00, 10291.72it/s]
# {'sushi': 'best sushi restaurant',
#  'sashimi': 'sashimi is really fresh',
#  'bento': 'highly recommend salmon bento box special'}

# %%
# review_text

# %%
# keyphrase_list

# %% [markdown]
# ## Loop through a list of restaurants

# %%
item_list = [3490,888,2666,820,2159,1796,1657,1367,215,2768,3758,2264,540,2427,1526,3740,166]

# %%
keyphrase_final_list = []
for i in item_list:
# get whole review text and the dataframe for this item
    review_text, df_business= get_business_review(i,df)
    # get all keyphrases and npTokenList(keyphrases before flatten --> partitioned keyphrase)
    Extracted_list,npTokenList = get_keyphrase_list(review_text)
    # get a noun list
    Noun_List = get_noun_list(npTokenList,stop_words_defined)
    # get a noun and it's score(dict_Counter(total frequency) * review_freq_counter(binary review frequency)), store in list
    top_noun_with_score = get_score_from_freq(Noun_List,review_text,df_business)
    # keyphrases that contrain the top nouns
    keyphrase_list = get_keyphrase_contain_topk(top_noun_with_score,top_k ,Extracted_list)
    # get dataframe for the keyphrases with vader score
    df_keyphrase = evalSentences(keyphrase_list, to_df=True,columns = ['keyphrase_list', 'Vader'])
    # get final keyphrases(one for each noun)
    keyphrase_final = get_final_keyphrase(df_keyphrase,top_k,top_noun_with_score)
    keyphrase_final_list.append([df_business[df_business["business_num_id"]==i].name.iloc[0],keyphrase_final])
# Out:
# 100%|█████████████████████████████████████████████████████████████████████| 137467/137467 [00:00<00:00, 2562912.33it/s]
# 100%|███████████████████████████████████████████████████████████████████████████| 7731/7731 [00:00<00:00, 29097.42it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 1319/1319 [00:00<00:00, 8488.25it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 868/868 [00:01<00:00, 567.97it/s]
# 100%|█████████████████████████████████████████████████████████████████████████| 1301/1301 [00:00<00:00, 1298926.33it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 598/598 [00:00<00:00, 23956.46it/s]
# 100%|███████████████████████████████████████████████████████████████████████| 65074/65074 [00:00<00:00, 2580457.38it/s]
# 100%|███████████████████████████████████████████████████████████████████████████| 3508/3508 [00:00<00:00, 50085.16it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 782/782 [00:00<00:00, 12606.40it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 416/416 [00:00<00:00, 936.79it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 775/775 [00:00<?, ?it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 217/217 [00:00<00:00, 21697.43it/s]
# 100%|███████████████████████████████████████████████████████████████████████| 57100/57100 [00:00<00:00, 2228272.78it/s]
# 100%|███████████████████████████████████████████████████████████████████████████| 2985/2985 [00:00<00:00, 46326.95it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 885/885 [00:00<00:00, 12829.68it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 363/363 [00:00<00:00, 828.69it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 875/875 [00:00<?, ?it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 175/175 [00:00<00:00, 24968.64it/s]
# 100%|███████████████████████████████████████████████████████████████████████| 51832/51832 [00:00<00:00, 2257613.66it/s]
# 100%|███████████████████████████████████████████████████████████████████████████| 2984/2984 [00:00<00:00, 51016.61it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 777/777 [00:00<00:00, 14421.90it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 275/275 [00:00<00:00, 767.09it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 772/772 [00:00<00:00, 760273.00it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 373/373 [00:00<00:00, 24887.06it/s]
# 100%|███████████████████████████████████████████████████████████████████████| 35342/35342 [00:00<00:00, 1368126.07it/s]
# 100%|███████████████████████████████████████████████████████████████████████████| 2073/2073 [00:00<00:00, 55706.21it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 491/491 [00:00<00:00, 15760.34it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 229/229 [00:00<00:00, 1477.61it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 479/479 [00:00<00:00, 495455.39it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 352/352 [00:00<00:00, 27085.84it/s]
# 100%|███████████████████████████████████████████████████████████████████████| 34028/34028 [00:00<00:00, 2563194.15it/s]
# 100%|███████████████████████████████████████████████████████████████████████████| 1998/1998 [00:00<00:00, 64088.55it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 578/578 [00:00<00:00, 13852.40it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 193/193 [00:00<00:00, 1140.14it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 571/571 [00:00<?, ?it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 139/139 [00:00<00:00, 27721.38it/s]
# 100%|███████████████████████████████████████████████████████████████████████| 26875/26875 [00:00<00:00, 2924044.62it/s]
# 100%|███████████████████████████████████████████████████████████████████████████| 1438/1438 [00:00<00:00, 67714.62it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 602/602 [00:00<00:00, 12138.64it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 160/160 [00:00<00:00, 1120.28it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 593/593 [00:00<00:00, 593892.62it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 166/166 [00:00<00:00, 23680.51it/s]
# 100%|███████████████████████████████████████████████████████████████████████| 24830/24830 [00:00<00:00, 1936276.51it/s]
# 100%|██████████████████████████████████████████████████████████████████████████| 1359/1359 [00:00<00:00, 101018.31it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 413/413 [00:00<00:00, 15848.12it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 148/148 [00:00<00:00, 1640.06it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 406/406 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 93/93 [00:00<00:00, 23149.57it/s]
# 100%|███████████████████████████████████████████████████████████████████████| 15088/15088 [00:00<00:00, 3025176.10it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 797/797 [00:00<00:00, 148512.16it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 327/327 [00:00<00:00, 16623.69it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 112/112 [00:00<00:00, 2338.19it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 321/321 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 52/52 [00:00<00:00, 25647.20it/s]
# 100%|███████████████████████████████████████████████████████████████████████| 14423/14423 [00:00<00:00, 3588471.15it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 887/887 [00:00<00:00, 51754.88it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 313/313 [00:00<00:00, 23206.54it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 99/99 [00:00<00:00, 2308.43it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 308/308 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 90/90 [00:00<00:00, 22406.80it/s]
# 100%|███████████████████████████████████████████████████████████████████████| 12298/12298 [00:00<00:00, 3057409.20it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 604/604 [00:00<00:00, 41520.96it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 260/260 [00:00<00:00, 16127.17it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 88/88 [00:00<00:00, 2756.26it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 259/259 [00:00<00:00, 259575.80it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 65/65 [00:00<00:00, 32172.50it/s]
# 100%|███████████████████████████████████████████████████████████████████████| 10116/10116 [00:00<00:00, 3344071.51it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 558/558 [00:00<00:00, 74244.89it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 236/236 [00:00<00:00, 26334.36it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 73/73 [00:00<00:00, 3045.82it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 231/231 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 86/86 [00:00<00:00, 28467.38it/s]
# 100%|█████████████████████████████████████████████████████████████████████████| 7729/7729 [00:00<00:00, 2549769.99it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 440/440 [00:00<00:00, 236177.86it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 245/245 [00:00<00:00, 34957.29it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 56/56 [00:00<00:00, 2802.98it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 244/244 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 46/46 [00:00<00:00, 23067.67it/s]
# 100%|█████████████████████████████████████████████████████████████████████████| 7060/7060 [00:00<00:00, 3479645.86it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 420/420 [00:00<00:00, 102514.41it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 239/239 [00:00<00:00, 47619.53it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 45/45 [00:00<00:00, 2649.33it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 238/238 [00:00<00:00, 238529.12it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 39/39 [00:00<00:00, 39086.70it/s]
# 100%|█████████████████████████████████████████████████████████████████████████| 4572/4572 [00:00<00:00, 4456508.92it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 187/187 [00:00<?, ?it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 107/107 [00:00<00:00, 53650.99it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 29/29 [00:00<00:00, 4156.04it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 107/107 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 12/12 [00:00<?, ?it/s]
# 100%|█████████████████████████████████████████████████████████████████████████| 1604/1604 [00:00<00:00, 1604498.84it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 85/85 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 64/64 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 14/14 [00:00<00:00, 6898.53it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 64/64 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 14/14 [00:00<00:00, 14051.27it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 980/980 [00:00<00:00, 953693.25it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 52/52 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 43/43 [00:00<00:00, 42099.69it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 9020.01it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 43/43 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 6016.21it/s]

# %%
keyphrase_final_list
# Out:
# [['Pai Northern Thai Kitchen',
#   {'thai': 'best authentic thai food',
#    'pad': 'pad thai is super flavourful',
#    'curry': 'delicious curry'}],
#  ['Hokkaido Ramen Santouka',
#   {'broth': 'awesome super rich broth',
#    'pork': 'pork is super',
#    'service': 'service is pretty fast'}],
#  ['Insomnia Restaurant & Lounge',
#   {'brunch': 'brunch is honestly amazing',
#    'service': 'pretty awesome customer service',
#    'insomnia': 'insomnia egg benny is quite impressive'}],
#  ['MeNami',
#   {'udon': 'udon is pretty tasty',
#    'sauce': 'cream sauce udon is pretty decent',
#    'corn': 'strong sweet corn taste'}],
#  ['GB Hand-pulled Noodles',
#   {'noodle': 'noodle are pretty decent',
#    'soup': 'soup is extremely delicious',
#    'beef': 'best beef noodle'}],
#  ['Ryus Noodle Bar',
#   {'broth': 'delicious rich broth',
#    'pork': 'delicious pork',
#    'service': 'service is excellent'}],
#  ["C'est What",
#   {'beer': 'good great craft beer selection',
#    'selection': 'selection is pretty good',
#    'service': 'excellent service'}],
#  ['KINTON RAMEN',
#   {'pork': 'pork miso ramen is amazing',
#    'broth': 'best broth',
#    'kinton': 'kinton amazing'}],
#  ['Kenzo Ramen',
#   {'service': 'service is excellent',
#    'kenzo': 'kenzo quite decent',
#    'broth': 'authentic broth'}],
#  ["India's Taste",
#   {'buffet': 'ayce buffet is really awesome',
#    'naan': 'best naan bread',
#    'chicken': 'butter chicken is really delicious'}],
#  ['Shawarma Empire',
#   {'shawarma': 'good authentic shawarma',
#    'chicken': 'chicken is delicious',
#    'beef': 'super yummy beef'}],
#  ['Bapbo Korean Restaurant',
#   {'korean': 'excellent korean place',
#    'service': 'excellent service',
#    'rice': 'incredible crispy rice'}],
#  ["Frankie's",
#   {'frankie': 'frankie original breakfast',
#    'service': 'service is fast',
#    'burger': 'best prepared veggie burger he'}],
#  ['Factory Girl',
#   {'service': 'service is pretty good',
#    'patio': 'decent patio',
#    'pizza': 'pizza is excellent'}],
#  ["Jack Astor's Bar & Grill",
#   {'service': 'excellent service',
#    'jack': 'jack astor',
#    'chicken': 'chicken strip'}],
#  ['Joy Thai Restaurant',
#   {'thai': 'best thai restaurant',
#    'service': 'service is friendly',
#    'chicken': 'chicken is good'}],
#  ['The Donlands Diner', {'diner': 'diner coffee', 'service': 'great service'}]]

# %% [markdown]
# ## Individual functions to test efficiency

# %%
review_text, df_business= get_business_review(business_num_id,df)

# %%
Extracted_list,npTokenList = get_keyphrase_list(review_text)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████| 7729/7729 [00:00<00:00, 2581855.34it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 440/440 [00:00<00:00, 221574.47it/s]

# %%
review_text
# Out:
# 'I\'ve been here at least 10 times, always was a god spot for breakfast. Service has absolutely turned to shit. Do not go here.One of the best grilled cheese sandwiches I\'ve had in awhile. Challah bread loaded with four cheeses (cheddar, blue, brie, and swiss). I. love. blue. cheese. The sweet fig jam they provide to dip it in is a nice change from the traditional ketchup (but do not worry they still give you ketchup too), and the side fries are the high quality chip truck, skin-on kind. Top it off with a can of pop and its really everything you need from a good diner dinner. Extras: service is fast, and you can easily get in and out for around $15-20 tax and tip included. The ambiance is nothing special but its pretty clean and comfy so it works.i cannot get enough of this place. 2nd time i went here within a week and they never disappoint. i had the fish with greek salad special...large amount and the fish w as delicious. excellent crunch factor. no fishy taste. and good batter. my friend had their turkey burger with sweet potato fries special. honestly, I\'ve never had a turkey burger before and this was the best burger i had in general. warm juicy patty, amazing toppings and the buns were whole wheat. the fries were delicious and large. would highly recommend this place for awesome eats at an affordable priceCheap and big portions of food. Came for Sunday brunch at around 10:45am and there was a backlog of parties waiting to be seated, but the tables were available. There were only 2 ladies working the entire floor so you really need to flag them down if you want anything... from ordering to getting a coffee refill. I ordered the big breakfast for $11 and I have to say this is one of the cheapest places I\'ve been to for Toronto breakfasts. Bacon/home fries/eggs/pancake were all amazing. I had a really empty stomach that morning and I still could not finish it.PSA they also charge an extra 25 cents if you pay with card.Had brunch here on the weekend. Was initially going somewhere in Liberty Village but a certain restaurant which did not allow for reservations had a wait time of up to 1.5 hours. Ridiculous. Anyhow, we walked around and came across to Frankie\'s. The only seats available was at the bar, which was fine. The service was good and the food came fairly quickly. I also liked the prices as it was not inflated like most places in the area since it was in downtown Toronto. Ordered the big breakfast. It was alright but I question the number of eggs used. The big breakfast is supposed to come with three eggs. I did ask for scrambled, and I usually make three at home also, but it looked more like 1.5 eggs were used. I had a huge craving for pancakes... but it was definitely better at I-Hop. But yummm Canadian Maple syrup !!Exactly what I wanted that morning - cheap, filling, fantastic breakfast. Nothing pretentious. Nothing over the top "gourmet", just sticking to the basics.SO...this ISN\'T THE BEST FOOD in the city, but it has / it is quite delicious considering the price point and it has / it is super convenient. I\'ve been here a couple of times and the food is consistent. The burger\'s a quite good (they actually taste like meat), and the onion rings are hot and fresh (though the french fries leave much to be desired, as they taste slightly of onion rings and are a little soggy). The chicken wings are good, while being large and super crispy! The price of everything is UNBELIEVABLY CHEAP, especially considering the location, and service is super friendly! I\'d definitely recommend at any point during the day (especially post drinking eats!) and will probably be back for just that!Came back with more people, ordered (mostly) different stuff, and I now think it has / it is worthy of a 5 star rating. They\'re still understaffed, and this was really apparent on a Saturday at brunch, but the food. The food.Frankie\'s #1 burger was again amazing. The meat is so ... meaty. Almost decadent, with how strong and beefy it is ...

# %%
npTokenList
# Out:
# [['god', 'spot'],
#  ['best', 'grilled', 'cheese', 'sandwich'],
#  ['challah', 'bread'],
#  ['sweet', 'fig', 'jam'],
#  ['nice', 'change'],
#  ['traditional', 'ketchup'],
#  ['high', 'quality', 'chip', 'truck'],
#  ['skin-on', 'kind'],
#  ['good', 'diner', 'dinner'],
#  ['extra', 'service'],
#  ['15-20', 'tax'],
#  ['large', 'amount'],
#  ['excellent', 'crunch', 'factor'],
#  ['fishy', 'taste'],
#  ['good', 'batter'],
#  ['turkey', 'burger'],
#  ['sweet', 'potato', 'fry'],
#  ['best', 'burger'],
#  ['warm', 'juicy', 'patty'],
#  ['amazing', 'topping'],
#  ['whole', 'wheat'],
#  ['awesome', 'eats'],
#  ['affordable', 'pricecheap'],
#  ['big', 'portion'],
#  ['sunday', 'brunch'],
#  ['entire', 'floor'],
#  ['big', 'breakfast'],
#  ['cheapest', 'place'],
#  ['really', 'empty', 'stomach'],
#  ['liberty', 'village'],
#  ['certain', 'restaurant'],
#  ['wait', 'time'],
#  ['downtown', 'toronto'],
#  ['huge', 'craving'],
#  ['yummm', 'canadian', 'maple', 'syrup'],
#  ['fantastic', 'breakfast'],
#  ['top', 'gourmet'],
#  ['best', 'food'],
#  ['super', 'convenient'],
#  ['french', 'fry'],
#  ['little', 'soggy'],
#  ['super', 'crispy'],
#  ['especially', 'post', 'drinking', 'eats'],
#  ['mostly', 'different', 'stuff'],
#  ['4-cheese', 'grilled', 'cheese'],
#  ['extra', 'brie'],
#  ['blue', 'cheese'],
#  ['fig', 'jam'],
#  ['perfect', 'accent', 'sweet'],
#  ['rocky', 'cheesesteak'],
#  ['original', 'breakfast'],
#  ['double', 'duty'],
#  ['short', 'wait'],
#  ['good', 'neighbourhood', 'place'],
#  ['downtown', 'brunch'],
#  ['rare', 'occasion'],
#  ['huge', 'plate'],
#  ['homemade', 'upscale', 'diner', 'goodness'],
#  ['reasonable', 'price'],
#  ['giant', 'square', 'plate'],
#  ['big', 'mac'],
#  ['lovin', 'buddy'],
#  ['slightly', 'undercooked', 'something'],
#  ['second', 'visit'],
#  ['fried', 'chicken'],
#  ['sweetest', 'service'],
#  ['tom', 'diner'],
#  ['great', 'food'],
#  ['5-10', 'star'],
#  ['large', 'fry'],
#  ['george', 'brown', 'college'],
#  ['maybe', 'fran'],
#  ['nice', 'shirt'],
#  ['young', 'lady'],
#  ['smile', 'consider'],
#  ['ice-cream', 'chocolate'],
#  ['web', 'site'],
#  ['associated', 'press'],
#  ['clean', 'hipster'],
#  ['comfortable', 'eating'],
#  ['nonsense', 'kind'],
#  ['real', 'complaint'],
#  ['different', 'menu'],
#  ['crispy', 'bacon'],
#  ['even', 'better', 'deal'],
#  ['tasty', 'lunch', 'yesterday'],
#  ['hot', 'fry'],
#  ['prompt', 'service'],
#  ['saturday', 'morning'],
#  ['egg', 'florentine'],
#  ['chicken', 'tender'],
#  ['tiny', 'sliver'],
#  ['little', 'container'],
#  ['good', 'salad'],
#  ['huge', 'fan'],
#  ['pure', 'oil'],
#  ['last', 'time'],
#  ['minimal', 'charge'],
#  ['french', 'toast'],
#  ['hard', 'time'],
#  ['standard', 'egg'],
#  ['toast', 'deal'],
#  ['real', 'bargain'],
#  ['best', 'breakfast'],
#  ['great', 'review'],
#  ['next', 'trip'],
#  ['oh', 'frankies'],
#  ['past', 'year'],
#  ['good', 'price'],
#  ['cheap', 'drink'],
#  ['tasty', 'grub'],
#  ['super', 'friendly', 'server'],
#  ['quick', 'lunch'],
#  ['good', 'burger'],
#  ['original', 'burger'],
#  ['burger', 'priest'],
#  ['soggy', 'burger'],
#  ['little', 'bit'],
#  ['bun', 'soggy'],
#  ['good', 'special'],
#  ['fancy', 'topping'],
#  ['burger', 'place'],
#  ['toronto', 'depend'],
#  ['fuss', 'burger'],
#  ['expect', 'fancy', 'burger'],
#  ['right', 'amount'],
#  ['hot', 'day'],
#  ['much', 'business'],
#  ['strawberry', 'milkshake'],
#  ['decent', 'beer', 'selection'],
#  ['extensive', 'menue'],
#  ['classic', 'cheeseburger'],
#  ['wooden', 'table'],
#  ['long', 'time'],
#  ['slow', 'day'],
#  ['large', 'selection'],
#  ['best', 'vegetarian', 'burger'],
#  ['soy', 'burger', 'moist', 'patty'],
#  ['potato', 'chip'],
#  ['new', 'friday', 'night', 'treat'],
#  ['original', 'burgerchili'],
#  ['cheese', 'friesit'],
#  ['restaurant', 'world'],
#  ['comfortable', 'place'],
#  ['bonus', 'point'],
#  ['open', 'early', 'till'],
#  ['grilled', 'chicken', 'caesar', 'salad'],
#  ['nice', 'big', 'portion'],
#  ['grilled', 'chicken'],
#  ['free', 'wifi'],
#  ['pokemon', 'go', 'player'],
#  ['stop', 'nearby'],
#  ['top', 'brunch', 'place'],
#  ['decent', 'portion'],
#  ['affordable', 'rate'],
#  ['6th', 'time'],
#  ['brunch', 'spot'],
#  ['queen', 'west'],
#  ['good', 'place'],
#  ['friendly', 'server'],
#  ['pulled', 'pork', 'egg'],
#  ['pulled', 'pork', 'sandwich'],
#  ['great', 'price'],
#  ['great', 'service'],
#  ['great', 'texture'],
#  ['nice', 'thin', 'cut', 'kind'],
#  ['soft', 'onion'],
#  ['bbq', 'sauce'],
#  ['big', 'mac', 'knockoff'],
#  ['6oz', 'patty'],
#  ['really', 'great', 'value'],
#  ['tasty', 'burger'],
#  ['last', 'sunday'],
#  ['original', 'place'],
#  ['pulled', 'pork', 'egg', 'benny'],
#  ['massive', 'portion'],
#  ['pulled', 'pork', 'benny'],
#  ['oh', 'man'],
#  ['reliable', 'breakfast'],
#  ['great', 'value'],
#  ['lower', 'ossington', 'theatre'],
#  ['like', 'medicine'],
#  ['little', 'bar'],
#  ['interesting', 'selection'],
#  ['huge', 'selection'],
#  ['smokin', 'hot', 'honey', 'burger'],
#  ['nice', 'place'],
#  ['cheap', 'place'],
#  ['brunch', 'breakfast'],
#  ['standard', 'american', 'breakfast', 'choice'],
#  ['dear', 'lord'],
#  ['much', 'flavor'],
#  ['pretty', 'decent', 'pricing'],
#  ['decent', 'burger'],
#  ['friendly', 'staff'],
#  ['fair', 'pricing'],
#  ['pulled', 'pork'],
#  ['certain', 'ingredient'],
#  ['fried', 'egg'],
#  ['best', 'prepared', 'veggie', 'burger', 'he'],
#  ['pretty', 'good', 'tasting'],
#  ['mill', 'street'],
#  ['hogtown', 'burger'],
#  ['deep', 'fried', 'pickle'],
#  ['pretty', 'fair', 'deal'],
#  ['eclectic', 'folk'],
#  ['small', 'group'],
#  ['bench', 'style', 'seat'],
#  ['real', 'curd'],
#  ['good', 'cuz'],
#  ['regular', 'thing', 'thou'],
#  ['good', 'size', 'cut'],
#  ['decent', 'quantity'],
#  ['great', 'place'],
#  ['enough', 'space'],
#  ['decent', 'amount'],
#  ['larger', 'group'],
#  ['usual', 'breakfast', 'brunch', 'item'],
#  ['ann', 'sather', 'review'],
#  ['smoked', 'salmon', 'benedict'],
#  ['next', 'best', 'thing'],
#  ['additional', 'side'],
#  ['actual', 'price'],
#  ['entire', 'meal'],
#  ['one-star', 'review'],
#  ['dietary', 'concern'],
#  ['cheaper', 'food'],
#  ['basic', 'breakfast'],
#  ['many', 'time'],
#  ['extra', 'large', 'slice'],
#  ['binocular', 'flask'],
#  ['guy', 'fieri'],
#  ['witness', 'protection', 'north'],
#  ['special', 'hangout'],
#  ['new', 'york', 'time'],
#  ['seminal', 'duo'],
#  ['fried', 'jalapeno'],
#  ['nacho', 'cheese', 'doritos', 'chip'],
#  ['nacho', 'cheese'],
#  ['friday', 'night'],
#  ['eclectic', 'mix'],
#  ['clientele', 'lot'],
#  ['underaged', 'asian'],
#  ['back', 'playing', 'solitaire'],
#  ['late', 'night', 'burger'],
#  ['greek', 'burger', 'hyuk', 'hyuk'],
#  ['drunk', 'people'],
#  ['friendly', 'waitress'],
#  ['good', 'spot'],
#  ['quick', 'bite'],
#  ['typical', 'diner'],
#  ['average', 'food'],
#  ['average', 'place'],
#  ['first', 'time'],
#  ['quick', 'lunch', 'food'],
#  ['small', 'size'],
#  ['different', 'side'],
#  ['decent', 'tasting', 'sandwich'],
#  ['half', 'price'],
#  ['greek', 'salad'],
#  ['cant', 'comment'],
#  ['delicious', 'option'],
#  ['good', 'food', 'doesnt'],
#  ['canadian', 'burger'],
#  ['high', 'rating'],
#  ['smoked', 'salmon', 'benny'],
#  ['crispy', 'af'],
#  ['full', 'brunch'],
#  ['small', 'town', 'feel'],
#  ['late', 'sunday', 'brunch'],
#  ['fresh', 'cucumber', 'tomato'],
#  ['infamous', 'old', 'fashion', 'burger'],
#  ['rare', 'patty'],
#  ['second', 'place'],
#  ['sweet', 'little', 'spot'],
#  ['impromptu', 'brunch'],
#  ['frankie', 'original', 'breakfast'],
#  ['hot', 'sauce'],
#  ['hard', 'side'],
#  ['busy', 'someone'],
#  ['timely', 'manner'],
#  ['overall', 'experience'],
#  ['little', 'confusing'],
#  ['big', 'deal'],
#  ['least', 'street'],
#  ['simple', 'place'],
#  ['good', 'reason'],
#  ['modern', 'diner'],
#  ['classic', 'diner', 'menu', 'item'],
#  ['large', 'group'],
#  ['classic', 'breakfast'],
#  ['much', 'better', 'quality'],
#  ['typical', 'diner', 'coffee'],
#  ['queen', 'ossington', 'area'],
#  ['aggressive', 'staff'],
#  ['bad', 'review'],
#  ['brown', 'hair'],
#  ['little', 'respect'],
#  ['fluish', 'wave'],
#  ['greasy', 'spoon'],
#  ['small', 'town', 'diner'],
#  ['dirty', 'grease'],
#  ['undercooked', 'potato'],
#  ['all-day-on-the-burner', 'coffee'],
#  ['good', 'value'],
#  ['classic', 'brunch', 'food'],
#  ['tuesday', 'morning'],
#  ['good', 'flavour'],
#  ['post-hangover', 'brunch'],
#  ['brunch', 'place'],
#  ['relatively', 'short', 'wait', 'time'],
#  ['sunday', 'afternoon'],
#  ['peameal', 'bacon'],
#  ['poached', 'egg'],
#  ['tangy', 'side'],
#  ['table', 'syrup'],
#  ['bad', 'place'],
#  ['brunch', 'scene'],
#  ['solid', 'brunch', 'breakfast', 'place'],
#  ['decent', 'lunch', 'option'],
#  ['nice', 'touch'],
#  ['long', 'wait', 'time'],
#  ['atmosphere', 'nice', 'mom', 'pop', 'shop', 'vibe'],
#  ['downtown', 'experience'],
#  ['service', 'is', 'fast'],
#  ['bun', 'were', 'whole'],
#  ['fry', 'were', 'delicious'],
#  ['table', 'were', 'available'],
#  ['service', 'was', 'good'],
#  ['food', 'is', 'consistent'],
#  ['everything', 'is', 'unbelievably', 'cheap'],
#  ['service', 'is', 'super'],
#  ['burger', 'was', 'amazing'],
#  ['pickle', 'were', 'really', 'good'],
#  ['ring', 'were', 'unimpeachable'],
#  ['cheese', 'was', 'perfect'],
#  ['toast', 'was', 'cold'],
#  ['hollandaise', 'sauce', 'was', 'heavy'],
#  ['was', 'also', 'unimpressed'],
#  ['labour', 'is', 'expensive'],
#  ['waitress', 'was', 'informative'],
#  ['salad', 'was', 'fresh'],
#  ['food', 'is', 'good'],
#  ['chicken', 'was', 'fresh'],
#  ['décor', 'is', 'functional'],
#  ['burger', 'were', 'fine'],
#  ['waitress', 'was', 'nice'],
#  ['service', 'is', 'great'],
#  ['service', 'was', 'friendly'],
#  ['menu', 'is', 'good'],
#  ['topping', 'were', 'plentiful'],
#  ['space', 'is', 'beautiful'],
#  ['service', 'was', 'slow'],
#  ['milkshake', 'was', 'soooo', 'good'],
#  ['service', 'is', 'fantastic'],
#  ['day', 'is', 'classic'],
#  ['experience', 'is', 'divine'],
#  ['burgerfrankie', 'original'],
#  ['server', 'is', 'enough'],
#  ['restaurant', 'free'],
#  ['service', 'was', 'great'],
#  ['restaurant', 'is', 'clean'],
#  ['frankie', 'reliable'],
#  ['burger', 'was', 'delicious'],
#  ['was', 'happy'],
#  ['staff', 'was', 'super', 'nice'],
#  ['star', 'review', 'is', 'due'],
#  ['was', 'pleasantly', 'surprised'],
#  ['food', 'menu', 'is', 'cheap'],
#  ['bill', 'was', 'low'],
#  ['burger', 'menu', 'is', 'extensive'],
#  ['frankie', 'original'],
#  ['gravy', 'was', 'hot'],
#  ['service', 'is', 'quite', 'slow'],
#  ['sauce', 'was', 'light'],
#  ['server', 'was', 'pretty', 'good'],
#  ['decor', 'is', 'really', 'basic'],
#  ['was', 'really', 'curious'],
#  ['price', 'point', 'is', 'great'],
#  ['fry', 'were', 'definitely', 'tasty'],
#  ['price', 'were', 'decent'],
#  ['fry', 'were', 'bad'],
#  ['souvaki', 'is', 'alright'],
#  ['reuben', 'was', 'small'],
#  ['fry', 'were', 'okay'],
#  ['ordered', 'frankie', 'original'],
#  ['everything', 'was', 'perfect'],
#  ['server', 'was', 'busy'],
#  ['was', 'sure'],
#  ['place', 'is', 'small'],
#  ['breakfast', 'is', 'affordable'],
#  ['restaurant', 'get', 'busy'],
#  ['staff', 'seems', 'sick'],
#  ['everything', 'was', 'solid'],
#  ['corn', 'beef', 'hash', 'was', 'indeed', 'delicious'],
#  ['franke', 'is', 'simple'],
#  ['downtown', 'toronto', 'is', 'extremely', 'popular'],
#  ['server', 'were', 'quick'],
#  ['food', 'arrived', 'relatively', 'quick'],
#  ['was', 'quite', 'disappointed'],
#  ['service', 'was', 'attentive'],
#  ['bacon', 'was', 'tasty'],
#  ['counter', 'were', 'friendly']]

# %%
tagger = PerceptronTagger()
pos_tag = tagger.tag
taggedToks = pos_tag([word.lower() for word in tqdm(re.findall(r'[\w]+-[\w]+[-[\w]+]?|[\w]+|[.,!?;]', review_text))])

# Create phrase tree
chunker1 = nltk.RegexpParser(grammar1)
tree1= chunker1.parse(taggedToks)
chunker2 = nltk.RegexpParser(grammar2)
tree2= chunker2.parse(taggedToks)

# Traverse tree and get noun phrases
npTokenList1 = [word for word in get_terms(tree1)]
# npTokenList
npTokenList2 = [word for word in get_terms(tree2)]
# Combine np token list to one
npTokenList_duplicate = npTokenList1 + npTokenList2
npTokenList = []
for i in tqdm(npTokenList_duplicate):
    if i not in npTokenList:
        npTokenList.append(i)


Extracted_list1 = flatten(npTokenList1)
Extracted_list2 = flatten(npTokenList2)
#Extracted_list = flatten([word
#                           for word
#                           in get_terms(chunker.parse(pos_tag([word.lower()
#                                                               for word in re.findall(r'\w+', review_text)])))])
Extracted_list = Extracted_list1 + list(set(Extracted_list2) - set(Extracted_list1))
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████| 7729/7729 [00:00<00:00, 2578159.35it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 440/440 [00:00<00:00, 220173.44it/s]

# %%
tree1
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\nltk\tree.py in _repr_png_(self)
#     795                         binary_names=['gswin32c.exe', 'gswin64c.exe'],
#     796                         env_vars=['PATH'],
# --> 797                         verbose=False,
#     798                     )
#     799                 ]
#
# C:\ProgramData\Anaconda3\lib\site-packages\nltk\internals.py in find_binary(name, path_to_bin, env_vars, searchpath, binary_names, url, verbose)
#     694     return next(
#     695         find_binary_iter(
# --> 696             name, path_to_bin, env_vars, searchpath, binary_names, url, verbose
#     697         )
#     698     )
#
# C:\ProgramData\Anaconda3\lib\site-packages\nltk\internals.py in find_binary_iter(name, path_to_bin, env_vars, searchpath, binary_names, url, verbose)
#     678     """
#     679     for file in find_file_iter(
# --> 680         path_to_bin or name, env_vars, searchpath, binary_names, url, verbose
#     681     ):
#     682         yield file
#
# C:\ProgramData\Anaconda3\lib\site-packages\nltk\internals.py in find_file_iter(filename, env_vars, searchpath, file_names, url, verbose, finding_dir)
#     636             msg += '\n\n  For more information on %s, see:\n    <%s>' % (filename, url)
#     637         div = '=' * 75
# --> 638         raise LookupError('\n\n%s\n%s\n%s' % (div, msg, div))
#     639
#     640
#
# LookupError:
#
# ===========================================================================
# NLTK was unable to find the gs file!
# Use software specific configuration paramaters or set the PATH environment variable.
# ===========================================================================
# Tree('S', [('i', 'NN'), ('ve', 'VBD'), ('been', 'VBN'), ('here', 'RB'), ('at', 'IN'), ('least', 'JJS'), ('10', 'CD'), ('times', 'NNS'), (',', ','), ('always', 'RB'), ('was', 'VBD'), ('a', 'DT'), Tree('NP', [Tree('NBAR', [('god', 'JJ'), ('spot', 'NN')])]), ('for', 'IN'), ('breakfast', 'NN'), ('.', '.'), ('service', 'NN'), ('has', 'VBZ'), ('absolutely', 'RB'), ('turned', 'VBN'), ('to', 'TO'), ('shit', 'VB'), ('.', '.'), ('do', 'VB'), ('not', 'RB'), ('go', 'VB'), ('here', 'RB'), ('.', '.'), ('one', 'CD'), ('of', 'IN'), ('the', 'DT'), Tree('NP', [Tree('NBAR', [('best', 'JJS'), ('grilled', 'JJ'), ('cheese', 'NN'), ('sandwiches', 'NNS')])]), ('i', 'VBP'), ('ve', 'NN'), ('had', 'VBD'), ('in', 'IN'), ('awhile', 'NN'), ('.', '.'), Tree('NP', [Tree('NBAR', [('challah', 'JJ'), ('bread', 'NN')])]), ('loaded', 'VBD'), ('with', 'IN'), ('four', 'CD'), ('cheeses', 'NNS'), ('cheddar', 'NN'), (',', ','), ('blue', 'NN'), (',', ','), ('brie', 'NN'), (',', ','), ('and', 'CC'), ('swiss', 'JJ'), ('.', '.'), ('i', 'NN'), ('.', '.'), ('love', 'NN'), ('.', '.'), ('blue', 'NN'), ('.', '.'), ('cheese', 'NN'), ('.', '.'), ('the', 'DT'), Tree('NP', [Tree('NBAR', [('sweet', 'JJ'), ('fig', 'JJ'), ('jam', 'NN')])]), ('they', 'PRP'), ('provide', 'VBP'), ('to', 'TO'), ('dip', 'VB'), ('it', 'PRP'), ('in', 'IN'), ('is', 'VBZ'), ('a', 'DT'), Tree('NP', [Tree('NBAR', [('nice', 'JJ'), ('change', 'NN')])]), ('from', 'IN'), ('the', 'DT'), Tree('NP', [Tree('NBAR', [('traditional', 'JJ'), ('ketchup', 'NN')])]), ('but', 'CC'), ('do', 'VBP'), ('not', 'RB'), ('worry', 'VB'), ('they', 'PRP'), ('still', 'RB'), ('give', 'VBP'), ('you', 'PRP'), ('ketchup', 'VB'), ('too', 'RB'), (',', ','), ('and', 'CC'), ('the', 'DT'), ('side', 'NN'), ('fries', 'NNS'), ('are', 'VBP'), ('the', 'DT'), Tree('NP', [Tree('NBAR', [('high', 'JJ'), ('quality', 'NN'), ('chip', 'NN'), ('truck', 'NN')])]), (',', ','), Tree('NP', [Tree('NBAR', [('skin-on', 'JJ'), ('kind', 'NN')])]), ('.', '.'), ('top', 'VB'), ('it', 'PRP'), ('off', 'RP'), ('with', 'IN'), ('a', 'DT'), ('can', 'MD'), ('of', 'IN'), ('pop', 'NN'), ('and', 'CC'), ('its', 'PRP$'), ('really', 'RB'), ('everything', 'NN'), ('you', 'PRP'), ('need', 'VBP'), ('from', 'IN'), ('a', 'DT'), Tree('NP', [Tree('NBAR', [('good', 'JJ'), ('diner', 'NN'), ('dinner', 'NN')])]), ('.', '.'), Tree('NP', [Tree('NBAR', [('extras', 'JJ'), ('service', 'NN')])]), ('is', 'VBZ'), ('fast', 'JJ'), (',', ','), ('and', 'CC'), ('you', 'PRP'), ('can', 'MD'), ('easily', 'RB'), ('get', 'VB'), ('in', 'IN'), ('and', 'CC'), ('out', 'IN'), ('for', 'IN'), ('around', 'IN'), Tree('NP', [Tree('NBAR', [('15-20', 'JJ'), ('tax', 'NN')])]), ('and', 'CC'), ('tip', 'NN'), ('included', 'VBD'), ('.', '.'), ('the', 'DT'), ('ambiance', 'NN'), ('is', 'VBZ'), ('nothing', 'NN'), ('special', 'JJ'), ('but', 'CC'), ('its', 'PRP$'), ('pretty', 'JJ'), ('clean', 'JJ'), ('and', 'CC'), ('comfy', 'VBZ'), ('so', 'RB'), ('it', 'PRP'), ('works', 'VBZ'), ('.', '.'), ('i', 'VB'), ('cannot', 'JJ'), ('get', 'VB'), ('enough', 'RB'), ('of', 'IN'), ('this', 'DT'), ('place', 'NN'), ('.', '.'), ('2nd', 'CD'), ('time', 'NN'), ('i', 'JJ'), ('went', 'VBD'), ('here', 'RB'), ('within', 'IN'), ('a', 'DT'), ('week', 'NN'), ('and', 'CC'), ('they', 'PRP'), ('never', 'RB'), ('disappoint', 'VBP'), ('.', '.'), ('i', 'NN'), ('had', 'VBD'), ('the', 'DT'), ('fish', 'NN'), ('with', 'IN'), ('greek', 'JJ'), ('salad', 'JJ'), ('special', 'JJ'), ('.', '.'), ('.', '.'), ('.', '.'), Tree('NP', [Tree('NBAR', [('large', 'JJ'), ('amount', 'NN')])]), ('and', 'CC'), ('the', 'DT'), Tree('NP', [Tree('NBAR', [('fish', 'JJ'), ('w', 'NN')])]), ('as', 'IN'), ('delicious', 'JJ'), ('.', '.'), Tree('NP', [Tree('NBAR', [('excellent', 'JJ'), ('crunch', 'NN'), ('factor', 'NN')])]), ('.', '.'), ('no', 'DT'), Tree('NP', [Tree('NBAR', [('fishy', 'JJ'), ('taste', 'NN')])]), ('.', '.'), ('and', 'CC'), Tree('NP', [Tree('NBAR', [('good', 'JJ'), ('batter', 'NN')])]), ('.', '.'), ('my', 'PRP$'), ('friend', 'NN'), ('had', 'VBD'), ('their', 'PRP$'), Tree('NP', [Tree('NBA ...

# %%
Noun_List = get_noun_list(npTokenList,stop_words_defined)

# %% [markdown]
# Compute the score for the noun list. Normalize by --> dict_Counter(total frequency) * review_freq_counter(binary review frequency)

# %%
top_word_list = get_score_from_freq(Noun_List,review_text,df_business)
top_word_list
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 868/868 [01:09<00:00, 12.46it/s]
# 100%|█████████████████████████████████████████████████████████████████████████| 1308/1308 [00:00<00:00, 1312790.05it/s]
# [['thai', 1043562],
#  ['pad', 320320],
#  ['curry', 243569],
#  ['pai', 155189],
#  ['khao', 151585],
#  ['get', 126208],
#  ['time', 125460],
#  ['wait', 96302],
#  ['service', 92868],
#  ['delicious', 88894],
#  ['rice', 75816],
#  ['soi', 75048],
#  ['back', 71874],
#  ['beef', 71269],
#  ['chicken', 63722],
#  ['try', 59125],
#  ['coconut', 58695],
#  ['green', 53600],
#  ['table', 49855],
#  ['sauce', 47232],
#  ['spicy', 41055],
#  ['bit', 40222],
#  ['menu', 39725],
#  ['toronto', 34848],
#  ['busy', 33174],
#  ['amazing', 32844],
#  ['love', 31059],
#  ['dinner', 27720],
#  ['atmosphere', 27040],
#  ['recommend', 26313],
#  ['pretty', 26226],
#  ['nice', 25702],
#  ['tea', 24339],
#  ['favourite', 20449],
#  ['sweet', 19926],
#  ['friend', 19270],
#  ['reservation', 18988],
#  ['spice', 18304],
#  ['lunch', 18212],
#  ['san', 18150],
#  ['gra', 17400],
#  ['everything', 17255],
#  ['soup', 15642],
#  ['noodle', 15105],
#  ['road', 14994],
#  ['pork', 14880],
#  ['prow', 13696],
#  ['shrimp', 13020],
#  ['squash', 12954],
#  ['right', 12947],
#  ['line', 12900],
#  ['super', 12625],
#  ['worth', 12614],
#  ['egg', 12028],
#  ['perfect', 11200],
#  ['eat', 10545],
#  ['crispy', 10057],
#  ['chef', 9657],
#  ['level', 9548],
#  ['salad', 9360],
#  ['drink', 9106],
#  ['thailand', 9072],
#  ['bar', 8798],
#  ['nuit', 8100],
#  ['tasty', 8084],
#  ['lot', 7910],
#  ['price', 7744],
#  ['feel', 7446],
#  ['flavourful', 7298],
#  ['loud', 7209],
#  ['decor', 7052],
#  ['yum', 6532],
#  ['staff', 6150],
#  ['fish', 6100],
#  ['area', 5950],
#  ['gaeng', 5848],
#  ['hour', 5704],
#  ['tender', 5680],
#  ['group', 5607],
#  ['something', 5589],
#  ['spring', 5544],
#  ['meat', 5124],
#  ['ice', 5100],
#  ['inside', 5025],
#  ['appetizer', 4928],
#  ['vibe', 4864],
#  ['server', 4680],
#  ['mango', 4368],
#  ['tom', 4070],
#  ['medium', 4060],
#  ['way', 4002],
#  ['fun', 3960],
#  ['downtown', 3840],
#  ['city', 3770],
#  ['eating', 3770],
#  ['papaya', 3750],
#  ['grabong', 3630],
#  ['water', 3432],
#  ['tamarind', 3400],
#  ['find', 3392],
#  ['cool', 3240],
#  ['seating', 3162],
#  ['top', 3132],
#  ['fan', 3016],
#  ['review', 2888],
#  ['creamy', 2688],
#  ['thought', 2544],
#  ['visit', 2430],
#  ['point', 2296],
#  ['street', 2288],
#  ['choice', 2280],
#  ['kind', 2254],
#  ['star', 2072],
#  ['quick', 2068],
#  ['mild', 2021],
#  ['ask', 1974],
#  ['music', 1968],
#  ['yummy', 1968],
#  ['space', 1927],
#  ['share', 1892],
#  ['end', 1890],
#  ['masaman', 1886],
#  ['peanut', 1856],
#  ['cannot', 1808],
#  ['flavor', 1769],
#  ['fast', 1764],
#  ['couple', 1680],
#  ['mind', 1665],
#  ['everyone', 1640],
#  ['party', 1632],
#  ['work', 1628],
#  ['milk', 1596],
#  ['option', 1586],
#  ['friday', 1558],
#  ['seat', 1539],
#  ['bite', 1530],
#  ['ambience', 1521],
#  ['start', 1521],
#  ['half', 1517],
#  ['home', 1517],
#  ['dessert', 1504],
#  ['lime', 1496],
#  ['kick', 1480],
#  ['garlic', 1480],
#  ['spiciness', 1462],
#  ['tofu', 1408],
#  ['item', 1400],
#  ['check', 1400],
#  ['favorite', 1395],
#  ['room', 1394],
#  ['wan', 1368],
#  ['style', 1365],
#  ['part', 1365],
#  ['unique', 1365],
#  ['dining', 1365],
#  ['advance', 1365],
#  ['ground', 1344],
#  ['saturday', 1296],
#  ['ambiance', 1296],
#  ['kiaw', 1190],
#  ['walk', 1188],
#  ['decent', 1155],
#  ['jasmine', 1140],
#  ['name', 1102],
#  ['add', 1092],
#  ['beer', 1080],
#  ['basil', 1054],
#  ['minute', 999],
#  ['cute', 992],
#  ['nothing', 992],
#  ['reason', 986],
#  ['look', 975],
#  ['whole', 961],
#  ['plate', 936],
#  ['texture', 875],
#  ['satay', 858],
#  ['course', 858],
#  ['weekday', 837],
#  ['chili', 832],
#  ['waitress', 816],
#  ['return', 812],
#  ['kitchen', 806],
#  ['mai', 806],
#  ['fritter', 784],
#  ['stir', 783],
#  ['awesome', 783],
#  ['broth', 750],
#  ['dip', 744],
#  ['savoury', 728],
#  ['hungry', 728],
#  ['average', 675],
#  ['sukho', 667],
#  ['sausage', 665],
#  ['starter', 665],
#  ['conversation', 660],
#  ['date', 660],
#  ['sabai', 656],
#  ['otherwise', 650],
#  ['salty', 650],
#  ['fact', 648],
#  ['door', 644],
#  ['foreigner', 638],
#  ['basement', 625],
#  ['attentive', 625],
#  ['bill', 616],
#  ['pricey', 600],
#  ['hype', 598],
#  ['evening', 594],
#  ['chiang', 594],
#  ['tip', 580],
#  ['sangria', 580],
#  ['guess', 576],
#  ['refreshing', 575],
#  ['cuisine', 572],
#  ['mix', 572],
#  ['balance', 572],
#  ['family', 567],
#  ['pla', 567],
#  ['serving', 567],
#  ['cold', 546],
#  ['roll', 534],
#  ['crowd', 532],
#  ['variety', 529],
#  ['rush', 529],
#  ['panang', 528],
#  ['crab', 525],
#  ['book', 525],
#  ['cocktail', 520],
#  ['veggie', 520],
#  ['min', 504],
#  ['arrive', 504],
#  ['kung', 500],
#  ['note', 494],
#  ['lineup', 493],
#  ['week', 490],
#  ['light', 486],
#  ['yelp', 484],
#  ['wow', 484],
#  ['environment', 483],
#  ['market', 483],
#  ['crunchy', 483],
#  ['sweetness', 483],
#  ['number', 480],
#  ['warm', 462],
#  ['oyster', 450],
#  ['town', 441],
#  ['year', 440],
#  ['afternoon', 440],
#  ['moo', 437],
#  ['tawt', 432],
#  ['leaf', 429],
#  ['dipping', 420],
#  ['coriander', 420],
#  ['presentation', 420],
#  ['complaint', 420],
#  ['tail', 408],
#  ['glass', 406],
#  ['noisy', 400],
#  ['glad', 400],
#  ['selection', 399],
#  ['opinion', 399],
#  ['mine', 399],
#  ['ate', 399],
#  ['weekend', 392],
#  ['hit', 384],
#  ['sai', 378],
#  ['heat', 368],
#  ['wednesday', 361],
#  ['dark', 360],
#  ['version', 360],
#  ['king', 360],
#  ['handle', 360],
#  ['app', 357],
#  ['massaman', 342],
#  ['lol', 342],
#  ['mouth', 342],
#  ['platter', 340],
#  ['potato', 336],
#  ['boyfriend', 336],
#  ['vegan', 330],
#  ['dim', 324],
#  ['interior', 324],
#  ['waiter', 324],
#  ['combination', 323],
#  ['takeout', 323],
#  ['lemongrass', 320],
#  ['hand', 320],
#  ['piece', 308],
#  ['simple', 306],
#  ['set', 304],
#  ['tum', 304],
#  ['stop', 289],
#  ['crazy', 289],
#  ['feeling', 288],
#  ['classic', 288],
#  ['chance', 285],
#  ['stuff', 272],
#  ['basa', 272],
#  ['bomb', 270],
#  ['life', 266],
#  ['skewer', 264],
#  ['sukhothai', 260],
#  ['district', 256],
#  ['bonus', 256],
#  ['use', 256],
#  ['peak', 256],
#  ['trendy', 256],
#  ['patio', 256],
#  ['floor', 255],
#  ['lighting', 255],
#  ['birthday', 252],
#  ['owner', 250],
#  ['breast', 247],
#  ['month', 242],
#  ['summer', 240],
#  ['tad', 240],
#  ['type', 238],
#  ['touch', 238],
#  ['tangy', 238],
#  ['hunglay', 238],
#  ['gai', 234],
#  ['entree', 230],
#  ['cozy', 225],
#  ['chill', 225],
#  ['list', 225],
#  ['greasy', 225],
#  ['ginger', 224],
#  ['som', 224],
#  ['pick', 224],
#  ['hipster', 221],
#  ['offer', 220],
#  ['value', 210],
#  ['issue', 204],
#  ['parking', 200],
#  ['kao', 196],
#  ['addition', 196],
#  ['longer', 196],
#  ['helpful', 196],
#  ['pow', 195],
#  ['section', 195],
#  ['juicy', 195],
#  ['phone', 195],
#  ['customer', 189],
#  ['hip', 182],
#  ['online', 182],
#  ['paste', 182],
#  ['recommendation', 180],
#  ['fillet', 180],
#  ['oxtail', 180],
#  ['bottom', 169],
#  ['perfection', 169],
#  ['thick', 169],
#  ['absolute', 169],
#  ['bunch', 169],
#  ['tasting', 169],
#  ['damn', 169],
#  ['hope', 169],
#  ['pay', 169],
#  ['house', 168],
#  ['care', 168],
#  ['ksr', 168],
#  ['thinking', 168],
#  ['chilli', 160],
#  ['drinking', 156],
#  ['fair', 156],
#  ['lack', 154],
#  ['guy', 153],
#  ['thursday', 144],
#  ['mood', 144],
#  ['dine', 144],
#  ['delivery', 144],
#  ['bamboo', 144],
#  ['efficient', 144],
#  ['problem', 144],
#  ['sunday', 143],
#  ['man', 143],
#  ['please', 143],
#  ['thamada', 143],
#  ['picture', 140],
#  ['fry', 132],
#  ['noise', 132],
#  ['bland', 132],
#  ['miang', 132],
#  ['turn', 130],
#  ['corner', 130],
#  ['morning', 121],
#  ['attention', 121],
#  ['ping', 121],
#  ['guest', 120],
#  ['trip', 120],
#  ['host', 120],
#  ['north', 120],
#  ['cost', 117],
#  ['hint', 117],
#  ['oil', 110],
#  ['mention', 110],
#  ['understand', 110],
#  ['change', 110],
#  ['standard', 108],
#  ['plan', 108],
#  ['bartender', 104],
#  ['chewy', 100],
#  ['notch', 100],
#  ['alcohol', 100],
#  ['continue', 100],
#  ['upbeat', 100],
#  ['luck', 100],
#  ['surprise', 99],
#  ['fit', 99],
#  ['joint', 96],
#  ['ratio', 90],
#  ['opening', 90],
#  ['decoration', 90],
#  ['crunch', 90],
#  ['winter', 90],
#  ['consistency', 90],
#  ['hostess', 90],
#  ['vibrant', 90],
#  ['fire', 90],
#  ['theatre', 90],
#  ['brisket', 90],
#  ['expectation', 88],
#  ['resto', 88],
#  ['shell', 88],
#  ['rating', 84],
#  ['lit', 81],
#  ['glory', 81],
#  ['signature', 81],
#  ['multiple', 81],
#  ['homemade', 81],
#  ['idea', 81],
#  ['take-out', 81],
#  ['authenticity', 81],
#  ['haha', 81],
#  ['core', 81],
#  ['betel', 81],
#  ['anyway', 80],
#  ['ton', 78],
#  ['mushroom', 78],
#  ['bean', 77],
#  ['laap', 77],
#  ['wise', 72],
#  ['juice', 72],
#  ['sugar', 72],
#  ['job', 72],
#  ['story', 72],
#  ['base', 72],
#  ['farang', 72],
#  ['liquor', 72],
#  ['container', 72],
#  ['beforehand', 72],
#  ['stand', 72],
#  ['cream', 70],
#  ['sign', 70],
#  ['wine', 70],
#  ['depth', 70],
#  ['vegetable', 68],
#  ['beat', 66],
#  ['system', 64],
#  ['playing', 64],
#  ['form', 64],
#  ['tho', 64],
#  ['sweeter', 64],
#  ['comfort', 64],
#  ['underground', 64],
#  ['sister', 64],
#  ['goodness', 64],
#  ['beware', 64],
#  ['cause', 64],
#  ['move', 63],
#  ['establishment', 63],
#  ['setting', 63],
#  ['fall', 63],
#  ['partner', 63],
#  ['cucumber', 60],
#  ['cabbage', 56],
#  ['sip', 56],
#  ['lychee', 56],
#  ['company', 56],
#  ['prik', 56],
#  ['reading', 56],
#  ['drumstick', 56],
#  ['preference', 56],
#  ['cuz', 56],
#  ['pineapple', 56],
#  ['boy', 56],
#  ['compliment', 54],
#  ['suko', 54],
#  ['office', 54],
#  ['wall', 52],
#  ['mak', 50],
#  ['pot', 49],
#  ['mediocre', 49],
#  ['holy', 49],
#  ['funky', 49],
#  ['tuesday', 49],
#  ['buttercup', 49],
#  ['omg', 49],
#  ['appeal', 49],
#  ['hearty', 49],
#  ['request', 49],
#  ['weather', 49],
#  ['runny', 49],
#  ['pleasant', 49],
#  ['batter', 49],
#  ['entrance', 49],
#  ['décor', 49],
#  ['richness', 49],
#  ['drank', 49],
#  ['background', 49],
#  ['protein', 48],
#  ['non', 48],
#  ['deal', 48],
#  ['coat', 48],
#  ['effort', 48],
#  ['tomato', 45],
#  ['range', 42],
#  ['blend', 42],
#  ['delight', 42],
#  ['fav', 42],
#  ['staple', 42],
#  ['wood', 42],
#  ['case', 42],
#  ['wing', 41],
#  ['event', 40],
#  ['pepper', 40],
#  ['meet', 40],
#  ['onion', 38],
#  ['convenient', 36],
#  ['combo', 36],
#  ['flame', 36],
#  ['bet', 36],
#  ['trust', 36],
#  ['express', 36],
#  ['disappointment', 36],
#  ['brick', 36],
#  ['neat', 36],
#  ['money', 36],
#  ['gotta', 36],
#  ['business', 36],
#  ['relaxing', 36],
#  ['tolerance', 36],
#  ['shot', 36],
#  ['charge', 36],
#  ['soooo', 36],
#  ['recall', 36],
#  ['palate', 36],
#  ['team', 36],
#  ['wooden', 36],
#  ['gang', 36],
#  ['factor', 35],
#  ['movie', 35],
#  ['random', 30],
#  ['volume', 30],
#  ['ingredient', 30],
#  ['explosion', 30],
#  ['stomach', 30],
#  ['imo', 30],
#  ['hook', 30],
#  ['winner', 30],
#  ['cup', 30],
#  ['tiff', 30],
#  ['break', 30],
#  ['caesar', 30],
#  ['rock', 30],
#  ['energy', 30],
#  ['phet', 30],
#  ['buzzer', 30],
#  ['mark', 30],
#  ['chang', 30],
#  ['gravy', 28],
#  ['bag', 28],
#  ['fruit', 28],
#  ['offering', 28],
#  ['savory', 25],
#  ['west', 25],
#  ['deliciousness', 25],
#  ['tiger', 25],
#  ['asia', 25],
#  ['legit', 25],
#  ['nua', 25],
#  ['stage', 25],
#  ['orange', 25],
#  ['baby', 25],
#  ['graw', 25],
#  ['plastic', 25],
#  ['moment', 25],
#  ['traffic', 25],
#  ['rate', 25],
#  ['beside', 25],
#  ['must-try', 25],
#  ['fai', 25],
#  ['penang', 25],
#  ['hotter', 25],
#  ['island', 25],
#  ['tax', 25],
#  ['ppl', 25],
#  ['line-up', 25],
#  ['monday', 25],
#  ['colourful', 25],
#  ['spiciest', 25],
#  ['communal', 25],
#  ['key', 25],
#  ['louder', 25],
#  ['excuse', 25],
#  ['spent', 25],
#  ['layout', 25],
#  ['example', 24],
#  ['mistake', 24],
#  ['refill', 24],
#  ['occasion', 21],
#  ['shake', 21],
#  ['butternut', 20],
#  ['chew', 20],
#  ['colour', 20],
#  ['relish', 20],
#  ['blowing', 20],
#  ['match', 20],
#  ['pricing', 20],
#  ['hubby', 20],
#  ['alternative', 20],
#  ['wave', 20],
#  ['quantity', 20],
#  ['soul', 20],
#  ['comment', 20],
#  ['temperature', 20],
#  ['complex', 20],
#  ['suit', 18],
#  ['twist', 18],
#  ['snack', 18],
#  ['bench', 18],
#  ['sooo', 16],
#  ['venture', 16],
#  ['khoa', 16],
#  ['crap', 16],
#  ['plah', 16],
#  ['advice', 16],
#  ['neighborhood', 16],
#  ['mixture', 16],
#  ['tai', 16],
#  ['consider', 16],
#  ['hidden', 16],
#  ['fare', 16],
#  ['comforting', 16],
#  ['mess', 16],
#  ['stay', 16],
#  ['mor', 16],
#  ['fatty', 16],
#  ['counter', 16],
#  ['caution', 16],
#  ['superb', 16],
#  ['challenge', 16],
#  ['station', 16],
#  ['standing', 16],
#  ['building', 16],
#  ['underwhelming', 16],
#  ['mini', 16],
#  ['majority', 16],
#  ['vacation', 16],
#  ['moving', 16],
#  ['waitlist', 16],
#  ['mushy', 16],
#  ['culture', 16],
#  ['design', 16],
#  ['complexity', 16],
#  ['intimate', 16],
#  ['control', 16],
#  ['cell', 16],
#  ['citrus', 16],
#  ['companion', 16],
#  ['pop', 16],
#  ['didnt', 16],
#  ['chaotic', 16],
#  ['skin', 16],
#  ['situation', 16],
#  ['mom', 16],
#  ['jam', 16],
#  ['scale', 16],
#  ['insane', 16],
#  ['royal', 15],
#  ['chunk', 15],
#  ['hett', 15],
#  ['chair', 15],
#  ['box', 15],
#  ['post', 15],
#  ['topping', 15],
#  ['round', 15],
#  ['dollar', 15],
#  ['wrap', 14],
#  ['diner', 12],
#  ['professional', 12],
#  ['yea', 12],
#  ['york', 12],
#  ['paper', 12],
#  ['flavouring', 12],
#  ['decision', 12],
#  ['game', 12],
#  ['comfy', 12],
#  ['chive', 12],
#  ['scene', 12],
#  ['detail', 12],
#  ['hole', 12],
#  ['store', 12],
#  ['weeknight', 12],
#  ['complement', 12],
#  ['pig', 12],
#  ['stew', 12],
#  ['bob', 12],
#  ['travel', 12],
#  ['shoot', 11],
#  ['beverage', 10],
#  ['patron', 10],
#  ['lover', 10],
#  ['buck', 10],
#  ['raptor', 10],
#  ['bottle', 10],
#  ['memory', 10],
#  ['arrangement', 10],
#  ['booth', 10],
#  ['shoe', 10],
#  ['bucket', 10],
#  ['art', 9],
#  ['availability', 9],
#  ['knick', 9],
#  ['pleasure', 9],
#  ['setup', 9],
#  ['pricy', 9],
#  ['prao', 9],
#  ['definite', 9],
#  ['standout', 9],
#  ['celebration', 9],
#  ['school', 9],
#  ['capacity', 9],
#  ['sale', 9],
#  ['tang', 9],
#  ['air', 9],
#  ['quieter', 9],
#  ['slice', 9],
#  ['foodie', 9],
#  ['southeast', 9],
#  ['jug', 9],
#  ['playlist', 9],
#  ['metal', 9],
#  ['dive', 9],
#  ['speed', 9],
#  ['substitute', 9],
#  ['adelaide', 9],
#  ['heaven', 9],
#  ['yolk', 9],
#  ['terrific', 9],
#  ['drawback', 9],
#  ['thirsty', 9],
#  ['nobody', 9],
#  ['aroma', 9],
#  ['retro', 9],
#  ['consideration', 9],
#  ['cafe', 9],
#  ['period', 9],
#  ['machine', 9],
#  ['relative', 9],
#  ['bud', 9],
#  ['support', 9],
#  ['restos', 9],
#  ['kitschy', 9],
#  ['lazy', 9],
#  ['cushion', 9],
#  ['burn', 9],
#  ['improvement', 9],
#  ['voice', 9],
#  ['guava', 9],
#  ['altho', 9],
#  ['marley', 9],
#  ['spoon', 9],
#  ['downfall', 9],
#  ['fiance', 9],
#  ['inexpensive', 9],
#  ['milky', 9],
#  ['gem', 8],
#  ['win', 8],
#  ['eater', 8],
#  ['larb', 8],
#  ['dinning', 8],
#  ['suggestion', 8],
#  ['gathering', 8],
#  ['attempt', 6],
#  ['pas', 6],
#  ['component', 6],
#  ['alot', 6],
#  ['drinker', 6],
#  ['country', 6],
#  ['wedge', 6],
#  ['hangout', 6],
#  ['sum', 6],
#  ['furniture', 6],
#  ['staircase', 6],
#  ['straw', 6],
#  ['clump', 6],
#  ['son', 6],
#  ['album', 6],
#  ['stool', 6],
#  ['score', 6],
#  ['grabang', 6],
#  ['distinctive', 6],
#  ['vodka', 6],
#  ['mat', 5],
#  ['bathroom', 5],
#  ['competent', 4],
#  ['november', 4],
#  ['news', 4],
#  ['lunchtime', 4],
#  ['lounge', 4],
#  ['pricer', 4],
#  ['alert', 4],
#  ['bass', 4],
#  ['fancy', 4],
#  ['sao', 4],
#  ['intolerance', 4],
#  ['ipa', 4],
#  ['adventure', 4],
#  ['yelling', 4],
#  ['soupy', 4],
#  ['piping', 4],
#  ['existent', 4],
#  ['relax', 4],
#  ['dimension', 4],
#  ['essence', 4],
#  ['roomier', 4],
#  ['garage', 4],
#  ['basis', 4],
#  ['expansion', 4],
#  ['page', 4],
#  ['opposite', 4],
#  ['profile', 4],
#  ['wok', 4],
#  ['mustard', 4],
#  ['good-looking', 4],
#  ['pink', 4],
#  ['height', 4],
#  ['shout', 4],
#  ['pace', 4],
#  ['inconvenient', 4],
#  ['flow', 4],
#  ['park', 4],
#  ['impression', 4],
#  ['land', 4],
#  ['diverse', 4],
#  ['marketplace', 4],
#  ['coconuty', 4],
#  ['sleepy', 4],
#  ['password', 4],
#  ['sense', 4],
#  ['suicide', 4],
#  ['hop', 4],
#  ['theme', 4],
#  ['mainstream', 4],
#  ['nook', 4],
#  ['kid', 4],
#  ['husk', 4],
#  ['culinary', 4],
#  ['plik', 4],
#  ['village', 4],
#  ['busiest', 4],
#  ['neighbor', 4],
#  ['imagination', 4],
#  ['dare', 4],
#  ['nicer', 4],
#  ['reco', 4],
#  ['jazz', 4],
#  ['extreme', 4],
#  ['ketchupy', 4],
#  ['proportion', 4],
#  ['neighbourhood', 4],
#  ['bias', 4],
#  ['watering', 4],
#  ['turnover', 4],
#  ['emphasis', 4],
#  ['ideal', 4],
#  ['length', 4],
#  ['tbh', 4],
#  ['recipe', 4],
#  ['highway', 4],
#  ['pile', 4],
#  ['degree', 4],
#  ['must-order', 4],
#  ['display', 4],
#  ['tower', 4],
#  ['america', 4],
#  ['border', 4],
#  ['tall', 4],
#  ['ranging', 4],
#  ['testament', 4],
#  ['countless', 4],
#  ['scream', 4],
#  ['twenty', 4],
#  ['syrup', 4],
#  ['pool', 4],
#  ['cherry', 4],
#  ['crush', 4],
#  ['phai', 4],
#  ['spinach', 4],
#  ['seafood', 4],
#  ['cayman', 3],
#  ['filet', 3],
#  ['element', 3],
#  ['omelette', 3],
#  ['leg', 3],
#  ['layer', 3],
#  ['accent', 3],
#  ['napkin', 3],
#  ['trinity', 3],
#  ['color', 3],
#  ['bae', 3],
#  ['orchid', 2],
#  ['womp', 2],
#  ['window', 2],
#  ['palette', 2],
#  ['pa', 2],
#  ['dig', 2],
#  ['dubai', 2],
#  ['ring', 2],
#  ['advantage', 2],
#  ['undertone', 2],
#  ['floater', 2],
#  ['critic', 2],
#  ['pha', 2],
#  ['vinegar', 2],
#  ['suspect', 2],
#  ['july', 2],
#  ['edge', 2],
#  ['kho', 2],
#  ['pudding', 2],
#  ['attitude', 2],
#  ['contrast', 2],
#  ['bkk', 2],
#  ['custard', 2],
#  ['disco', 2],
#  ['scallion', 2],
#  ['corriander', 2],
#  ['inch', 2],
#  ['chart', 2],
#  ['concept', 2],
#  ['destination', 2],
#  ['waitor', 2],
#  ['ramp', 1],
#  ['elevator', 1],
#  ['takeaway', 1],
#  ['bubbletea', 1],
#  ['curacao', 1],
#  ['exterior', 1],
#  ['disconnect', 1],
#  ['process', 1],
#  ['grass', 1],
#  ['dundas', 1],
#  ['sarn', 1],
#  ['grail', 1],
#  ['vacant', 1],
#  ['nite', 1],
#  ['sea', 1],
#  ['crusty', 1],
#  ['flight', 1],
#  ['cleanser', 1],
#  ['transit', 1],
#  ['tatami', 1],
#  ['check-out', 1],
#  ['daythe', 1],
#  ['efficientthe', 1],
#  ['billsthey', 1],
#  ['muchbeer', 1],
#  ['lapsmy', 1],
#  ['estimate', 1],
#  ['lager', 1],
#  ['trend', 1],
#  ['parliament', 1],
#  ['steet', 1],
#  ['layering', 1],
#  ['bar-seating', 1],
#  ['duo', 1],
#  ['galentine', 1],
#  ['trim', 1],
#  ['itthe', 1],
#  ['batch', 1],
#  ['icce', 1],
#  ['diego', 1],
#  ['ohhhh', 1],
#  ['convo', 1],
#  ['sui', 1],
#  ['thereof', 1],
#  ['rip', 1],
#  ['textury', 1],
#  ['experiment', 1],
#  ['salada', 1],
#  ['servicea', 1],
#  ['decorfun', 1],
#  ['warehouse', 1],
#  ['cheat', 1],
#  ['effy', 1],
#  ['diner5', 1],
#  ['regretful', 1],
#  ['stint', 1],
#  ['rom-com', 1],
#  ...]

# %%
keyphrase_list = get_keyphrase_contain_topk(top_word_list,top_k ,Extracted_list)
keyphrase_list
# Out:
# ['usual thai restaurant',
#  'chicken pad thai',
#  'favourite thai restaurant',
#  'traditional thai',
#  'best tasting pad thai',
#  'green curry',
#  'average thai restaurant',
#  'thai takeaway place',
#  'competent thai restaurant',
#  'curry-based broth',
#  'already delicious coconut-based curry',
#  'pad thai',
#  'red curry',
#  'main course panang curry',
#  'chopped thai chilli',
#  'thai restaurant',
#  'best thai food',
#  'thai craving',
#  'pad gra pow',
#  'green curry chicken shrimp',
#  'favourite thai place',
#  'authentic thai food',
#  'average thai food',
#  'classic pad',
#  'northern thai sweet',
#  'northern thailand',
#  'best thai restaurant',
#  'best pad thai',
#  'pad thai cannot',
#  'good thai place',
#  'thai place',
#  'typical thai dish',
#  'favourite pad thai',
#  'yellow curry sauce',
#  'good thai food',
#  'thai spot',
#  'thai style',
#  'authentic thai',
#  'especially thai cuisine',
#  'new favorite thai place',
#  'thai dish',
#  'great phad thai',
#  'massaman beef curry',
#  'classic thai-style chicken flavor',
#  'thai-styled fried egg',
#  'classic pad thai',
#  'authentic thai restaurant right',
#  'pai northern thai kitchen',
#  'delicious thai cuisine',
#  'thai chilies',
#  'favourite thai spot',
#  'northern thai sausage pork sausage',
#  'thai relish',
#  'great thai foodwow',
#  'green curry dish',
#  'fancy thai',
#  'popular thai ice tea',
#  'thai tea',
#  'thai cuisine',
#  'thai coriander',
#  'real thai food',
#  'next thai food adventure',
#  'thai ice tea',
#  'decent thai food',
#  'best thai food place',
#  'thai beer',
#  'solid thai restaurant',
#  'braised beef curry',
#  'thai food',
#  'really good thai food',
#  'golden curry',
#  'typical thai restaurant',
#  'northern thai style',
#  'tasty thai spice',
#  'go-to thai place',
#  'best pad gra',
#  'mak mak thai spicy',
#  'authentic thai experience',
#  'curry coconut soup',
#  'really solid thai food',
#  'excellent thai cuisine',
#  'great curry flavor',
#  'best thai place',
#  'great thai restaurant',
#  'authentic northern thai food',
#  'tasty thai food',
#  'northern thai dish',
#  'best thai curry',
#  'ho-hum neighborhood thai place',
#  'always pad thai',
#  'fish curry',
#  'select thai restaurant',
#  'phenomenally fragrant green curry',
#  'anymore thai place',
#  'hot beef pad',
#  'vegetable pad thai',
#  'thai experience',
#  'creamy coconut curry sauce',
#  'regular thai place',
#  'sukho thai',
#  'northern thai homemade pork',
#  'spiciest level thai spicy',
#  'delicious curry',
#  'good curry',
#  'awesome thai food',
#  'thai basil',
#  'finest thai food',
#  'great thai food',
#  'pad tai',
#  'pad gra prow',
#  'excellent thai food',
#  'decent pad thai',
#  'northern thai sausage platter appetizer',
#  'delicious delicious curry',
#  'thai express',
#  'traditional style thai',
#  'best green curry',
#  'new favourite thai restaurant',
#  'delicious thai food',
#  'northern thai sausage',
#  'fancy-ish authetic thai establishment',
#  'best thai',
#  'great overall thai restaurant',
#  'thai option',
#  'best thai food downtown',
#  'creamy golden curry',
#  'busy energetic thai place',
#  'fav thai place',
#  'sukhothai location',
#  'authentic casual thai vibe',
#  'green coconut curry',
#  'curry lovin soup fan',
#  'northern thai kitchen fun place',
#  'so-called thai placespai',
#  'popular thai restaurant',
#  'flavorful curry',
#  'good thai street food',
#  'many thai restaurant',
#  'flavourful pad thai',
#  'basically green curry',
#  'different thai restaurant',
#  'fish pad gra prow',
#  'unique thai environment',
#  'favourite thai dish',
#  'green curry sauce',
#  'curry dish',
#  'similar place sukhothai',
#  'pai northern thai',
#  'thai street food stall',
#  'watered-down curry',
#  'little green curry',
#  'milky sweet thai',
#  'good go-to thai restaurant',
#  'jamaican-thai feel',
#  'northern thai cuisine',
#  'rich coconut curry broth',
#  'authentic thai restaurant',
#  'beautiful thailand',
#  'thai land',
#  'ordered thai spicy',
#  'authdntic thai heat',
#  'really good thai',
#  'vegan dish pad pha hett',
#  'good thai restaurant',
#  'better thai restaurant',
#  'certainly cheaper thai restaurant',
#  'nice little thailand feel',
#  'delicious shrimp pad thai',
#  'green curry chicken',
#  'famous pad thai',
#  'spiked thai tea',
#  'northern thai kitchen',
#  'combine traditional thai decor',
#  'ubereats dinner pad thai',
#  'best thai joint downtown',
#  'favorite thai restaurant',
#  'traditional thai dish',
#  'amazing northern thai dish',
#  'thai laap paste',
#  'preselected curry',
#  'thai omelette',
#  'favorite thai dessert',
#  'presumably thai military men',
#  'much curry',
#  'incredible pad thai',
#  'traditional northern thai kitchen',
#  'delicious thai meal',
#  'shrimp-gaeng masaman-pad thai-thai ice',
#  'tea-thai ice tea ice',
#  'thai ice tea ice cream',
#  'best thai resto',
#  'thai chili',
#  'nuir pad thai',
#  'regularly eat thai food',
#  'red penang curry',
#  'nice thailand feel',
#  'thai street food market',
#  'consistently delicious thai place',
#  'thai papaya salad',
#  'fav thai dish',
#  'new favourite thai resto',
#  'delicious northern thai food',
#  'san road pad thai',
#  'first sukho thai',
#  'latest delicious thai restaurant',
#  'ox tail curry',
#  'original sukhothai',
#  'sukhothai pad thai',
#  'green chicken curry',
#  'strong thai flavour',
#  'ox tail ginger curry',
#  'golden curry sauce',
#  'great thai spot',
#  'new thai restaurant',
#  'green curry spiciness',
#  'really good thai restaurant',
#  'really good pad thai',
#  'fantastic northern thai restaurant',
#  'inferior ketchup-based pad thai',
#  'gaeng masaman tamarind curry',
#  'sour ginger curry',
#  'aromatic thai herb',
#  'fav thai food',
#  'proper thai restaurant',
#  'thai spicy',
#  'genuine thai flavour',
#  'saturated thai cuisine scene',
#  'far pad gra prow',
#  'fish green curry',
#  'super tender beef massaman curry',
#  'many good thai food',
#  'authentic thai pad thai',
#  'delicious pad thai',
#  'pad thai dish',
#  'real authentic thai food',
#  'good pad thai',
#  'basic asian tasting curry',
#  'simple thai food',
#  'much thai food',
#  'red curry paste batter',
#  'northern thai sausage pork',
#  'delectable coconut milk curry',
#  'real good curry',
#  'authentic thai restauraunt',
#  'masaman curry',
#  'chickenkhao pad',
#  'take-out thai place',
#  'thai phase',
#  'regular thai food',
#  'latest thai restaurant',
#  'good northern thai',
#  'great thai place',
#  'thai foodpai',
#  'usual thai expectation',
#  'normal thai restaurant',
#  'pad gra',
#  'truly authentic thai place',
#  'thick curry',
#  'vegetarian pad thai',
#  'green curry luxuriant',
#  'authentic thai food pai',
#  'favorite thai dish',
#  'pretty subpar thai option',
#  'red thai curry',
#  'really good thai place',
#  'curry fiend',
#  'authentic northern thai restaurant',
#  'pai northern thai kitchen transfer',
#  'thai hot sauce',
#  'yellow curry',
#  'sub-standard pad thai',
#  'thai family',
#  'northern thai',
#  'top thai food place',
#  'golden thai restaurant',
#  'peanut-based curry',
#  'best curry',
#  'authentic thai selection',
#  'sister restaurant sukho thai',
#  'yellow curry khao soi',
#  'north thai plate',
#  'authentic thailand style spicy',
#  'real pad thai',
#  'curry take-away',
#  'spicymy new favourite thai restaurant',
#  'upcoming thailand vacation',
#  'northern thai section',
#  'pad thai noodle',
#  'green curry thai spicy',
#  'authentic thai place',
#  'northern thai food',
#  'tasty curry sauce',
#  'solid pad thai',
#  'outstanding thai',
#  'green curry rice',
#  'panang curry curry',
#  'thai aromatics',
#  'mine thai spice',
#  'trendy thai restaurant',
#  'vegan pad thai',
#  'hipster thai resto',
#  'simplest pad',
#  'soi curry',
#  'thai milk tea',
#  'thai shack',
#  'thai choice',
#  'chef nuit pad thai',
#  'amazing pad thai',
#  'thai market',
#  'green curry vegan',
#  'heir thai ice',
#  'hands-down best thai food',
#  'typically pad thai',
#  'favorite thai spot',
#  'thai style chicken wing',
#  'gaeng masaman curry',
#  'iconic toronto thai restaurant',
#  'delicious green curry',
#  'great curry',
#  'suko thai',
#  'top thai restaurant',
#  'infamous thai',
#  'favourite thai placescozy basement ambiance',
#  'thai bucket',
#  'ugly khao pad thamada',
#  'scrumptious thai meal',
#  'thai resturants',
#  'deep curry flavour',
#  'good-looking thai dish',
#  'green red curry',
#  'classic thai comfort food',
#  'perfect thai curry',
#  'subtle street-style pad thai sauce',
#  'thai spice',
#  'good thai',
#  'thai accent',
#  'thai excellence',
#  'real thai food taste',
#  'main chicken curry dish',
#  'horrid pad thai',
#  'solid thai food',
#  'red curry dish',
#  'simply phenomenal backpacker-style northern thai food',
#  'additional green curry',
#  'authentic thai street food',
#  'bkk thai',
#  'extra curry',
#  'many pad',
#  'expensive thai food place',
#  'wrong curry dish',
#  'thai ingredient',
#  'favourite thai option',
#  'faaaavourite thai restos',
#  'following chef nuit pad thai',
#  'classic thai',
#  'fake pad thai',
#  'sweet sour curry',
#  'sour curry',
#  'red curry chicken',
#  'northern thai sausage platter',
#  'better thai',
#  'thai spicy level',
#  'excellent thai',
#  'interesting nice thai accent',
#  'high quality thai food',
#  'lively thai restaurant',
#  'oyster saucepad thai',
#  'seriously delicious pad thai',
#  'many pad thai place',
#  'thai picture',
#  'best pad thai place',
#  'americanized pad thai joint',
#  'sweet coconut curry',
#  'awesome thai food coconut water',
#  'canadian thai',
#  'thai custard',
#  'better thai experience',
#  'first thai restaurant',
#  'new curry',
#  'isan thai place downtown',
#  'pad thamada beef',
#  'pad thai chicken',
#  'mild chicken pad thai',
#  'thai milkshake',
#  'distinctive thai restaurant',
#  'southern thailand',
#  'special pad gra prow',
#  'thai resto',
#  'thai street restaurant vibe',
#  'green coconut curry fish',
#  'thai wing',
#  'red sauce pad thai',
#  'red creamy coconut curry',
#  'excellent thai food spot',
#  'open northern thai experience',
#  'thai scene',
#  'authentic thai food experience',
#  'yummy thai restaurant',
#  'many great thai place',
#  'pretty much thai food',
#  'busy northern thai haunt truly',
#  'north thailand',
#  'gaeng hunglay ox tail curry',
#  'green thai curry',
#  'extra curry sauce',
#  'golden curry dish',
#  'delicious northern thai cuisine',
#  'chef nuit chicken pad thai platter',
#  'upper-end thai restaurant',
#  'exactly scream thai',
#  'current favorite thai restaurant',
#  'proper thai place',
#  'popular thai place',
#  'amazing thai food',
#  'pop-thai place',
#  'generic thai spot',
#  'regular thai tea',
#  'frequent thai tea',
#  'authentic thai eats',
#  'ua northern thai sausage',
#  'better shrimp pad thai',
#  'khao san road sukho thai',
#  'best authentic thai food',
#  'great authentic thai food',
#  'paimy favourite thai restaurant',
#  'best thai food restaurant',
#  'great authentic thai',
#  'open thai market feel',
#  'sweet thai chili sauce',
#  'super flavourful curry',
#  'awesome thai meal',
#  'favourite curry',
#  'go-to thai restaurant',
#  'northen thai kitchen',
#  'yummy pad thai',
#  'thai style curry',
#  'special thai dessert',
#  'popular northern thai place',
#  'sour ox tail ginger curry',
#  'authentic pad thai',
#  'pad thai mild',
#  'proper thai basil',
#  'definitely true thai',
#  'pad thai dishclean',
#  'best thai meal',
#  'green curry panang curry',
#  'favourite go-to thai restaurant',
#  'thai spiciness',
#  'tried-chef nuit pad thai',
#  'gravy curry',
#  'favorite thai restaurant downtown',
#  'thai people',
#  'thai venture',
#  'regular spicy curry',
#  'itgreen curry chicken',
#  'top notch thai restaurant',
#  'real authentic thai foodthis',
#  'favorite thai place',
#  'thai sausage',
#  'new thai',
#  'flavour green curry',
#  'thai soundtrack',
#  'beautiful golden curry',
#  'classic thai dish',
#  'northern style thai food',
#  'pad gra prow ground pork',
#  'salted crab pad thai gang',
#  'green currythe wing',
#  'pad thai perfect',
#  'curry sauce is rich',
#  'thai kitchen opened couple',
#  'thai is excellent',
#  'pad thai was delicious',
#  'pad thai is amazing',
#  'curry shrimp',
#  'chef nuit pad thai was good',
#  'oad thai was really good',
#  'pad thai is great',
#  'curry is incredibly deep',
#  'curry is awesome',
#  'curry was absolutely amazing',
#  'thai food is quite delicious',
#  'thai tea was delicious',
#  'place serf pad thai',
#  'beef curry was also great',
#  'curry sauce was creamy',
#  'curry is flavourful',
#  'curry was herby',
#  'thai heat was spicy',
#  'pai thai was good overall',
#  'coconut curry was rich',
#  'curry was phenomenal',
#  'thai tea is good',
#  'pad gra pow basil was fragrant',
#  'pad thai was reasonably good',
#  'pad gra prow offered many familiar',
#  'thai was pretty darn good',
#  'curry was good',
#  'pad gra prow was tasty',
#  'felt sukhothai',
#  'green-curry is really nice',
#  'curry is dense',
#  'pad thai was prob',
#  'pad thai was good',
#  'curry was nice',
#  'curry was delicious',
#  'milky roasted thai',
#  'pad gra prow is deceptively simple',
#  'pad thai was super flavourful',
#  'craved thai',
#  'pad thai is overly',
#  'curry taste delicious',
#  'curry were flavourful',
#  'thai iced tea nice',
#  'thai was decent',
#  'pad thai was flavorful',
#  'pad thai is pretty good',
#  'pad thai was ho-hum',
#  'pad thai was simple',
#  'pad thai was rich',
#  'pad thai was spectacular',
#  'curry was sweet',
#  'pad thai tofu veggie is good',
#  'curry is sooo flavourful',
#  'pad thai is generously-portioned',
#  'thai restaurant is pad',
#  'curry is mind',
#  'curry is outstanding',
#  'thai spawned koh san',
#  'chef nuit pad thai is really good',
#  'curry chicken was creamy',
#  'curry is fragrant',
#  'home made thai hot',
#  'thai food is always pad',
#  'curry flavor was good',
#  'dish was pad',
#  'curry is cute',
#  'khao pad thamada was good',
#  'pad gra prow was good',
#  'pad thai was quite delicious',
#  'curry was fine',
#  'pad thai was perfect',
#  'pad thai is delicious',
#  'curry was flavourful',
#  'thai tea is super good',
#  'curry is delicious',
#  'panang curry good',
#  'bit thai is normally super inexpensive',
#  'curry broth was rich',
#  'pad thai was authentic',
#  'pad thai is excellent',
#  'thai food is worth',
#  'curry was creamy',
#  'pad gra prow was absolutely delicious',
#  'chef nuit pad thai was pretty good',
#  'pad thai was also great',
#  'coconut milk curry is delicious',
#  'curry was authentic',
#  'thai iced tea',
#  'water pad thai was nice',
#  'curry rice is delicious',
#  'curry was medium',
#  'curry was overly',
#  'beefthe pad thai was similar',
#  'pad thai is pretty',
#  'curry was full',
#  'pad thai was creamy',
#  'pad thai good',
#  'pad gra prao is delicious',
#  'curry was rich',
#  'oxtail curry is pretty sweet',
#  'curry soup was nice',
#  'chef nuit pad thai was tasty',
#  'curry is rich',
#  'pad thai distinctive',
#  'phai thai is also amazing',
#  'nuit pad thai is good',
#  'pad thai equal',
#  'curry flavour was unique',
#  'pad thai was light',
#  'pad gra prow was really good',
#  'curry was tasty',
#  'pad ga prow was flawless',
#  'thailand great',
#  'curry come mild',
#  'pad gra prow were excellent',
#  'curry sauce was perfectly crispy',
#  'pad thai was exceptional',
#  'pad thai is also spectacular',
#  'thai bucket is fun',
#  'curry was really good',
#  'curry is quite filling',
#  'lol thai iced tea',
#  'thai was good',
#  'curry is quite adequate',
#  'curry is nice',
#  'curry was perfect']

# %% [markdown]
# Update Vader score for the keyphrase list

# %%
df_keyphrase = evalSentences(keyphrase_list, to_df=True,columns = ['keyphrase_list', 'Vader'])
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 597/597 [00:00<00:00, 22144.98it/s]

# %%
df_keyphrase.sort_values("Vader", ascending = False, inplace = True)
df_keyphrase
# Out:
#                             keyphrase_list   Vader
# 422               best authentic thai food  0.8990
# 113              delicious delicious curry  0.8979
# 423              great authentic thai food  0.8770
# 426                   great authentic thai  0.8770
# 508          pad thai was super flavourful  0.8624
# 429                 super flavourful curry  0.8624
# 256             truly authentic thai place  0.8347
# 544                 thai tea is super good  0.7783
# 129             authentic casual thai vibe  0.7763
# 330              classic thai comfort food  0.7579
# 480           curry was absolutely amazing  0.7410
# 539           pad thai was quite delicious  0.7386
# 481           thai food is quite delicious  0.7386
# 553  pad gra prow was absolutely delicious  0.7386
# 570           oxtail curry is pretty sweet  0.7351
# 496              thai was pretty darn good  0.7269
# 554     chef nuit pad thai was pretty good  0.7269
# 516                pad thai is pretty good  0.7269
# 393               excellent thai food spot  0.7176
# 80                  excellent thai cuisine  0.7176
# 550                  pad thai is excellent  0.7176
# 471                      thai is excellent  0.7176
# 362                         excellent thai  0.7176
# 110                    excellent thai food  0.7176
# 585            pad gra prow were excellent  0.7176
# 177             amazing northern thai dish  0.7168
# 575              phai thai is also amazing  0.7168
# 413                      amazing thai food  0.7168
# 307                       amazing pad thai  0.7168
# 473                    pad thai is amazing  0.7168
# ..                                     ...     ...
# 278           sister restaurant sukho thai  0.0000
# 275                     peanut-based curry  0.0000
# 274                 golden thai restaurant  0.0000
# 272                          northern thai  0.0000
# 271                            thai family  0.0000
# 270                  sub-standard pad thai  0.0000
# 269                           yellow curry  0.0000
# 268                         thai hot sauce  0.0000
# 267     pai northern thai kitchen transfer  0.0000
# 265                            curry fiend  0.0000
# 263                         red thai curry  0.0000
# 259                  green curry luxuriant  0.0000
# 257                            thick curry  0.0000
# 253                 usual thai expectation  0.0000
# 245                        chickenkhao pad  0.0000
# 246                    take-out thai place  0.0000
# 247                             thai phase  0.0000
# 248                      regular thai food  0.0000
# 249                 latest thai restaurant  0.0000
# 252                           thai foodpai  0.0000
# 254                 normal thai restaurant  0.0000
# 255                                pad gra  0.0000
# 298                 trendy thai restaurant  0.0000
# 148                 thai street food stall -0.2023
# 409                    exactly scream thai -0.4019
# 218        inferior ketchup-based pad thai -0.4019
# 349                       wrong curry dish -0.4767
# 355                          fake pad thai -0.4767
# 324                  ugly khao pad thamada -0.5106
# 339                        horrid pad thai -0.5423
#
# [597 rows x 2 columns]

# %%
dictionary = get_final_keyphrase(df_keyphrase,top_k,top_word_list)
dictionary
# Out:
# {'thai': 'best authentic thai food',
#  'pad': 'pad thai was super flavourful',
#  'curry': 'delicious curry'}
