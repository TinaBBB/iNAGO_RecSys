# %%
import pandas as pd
import json
import matplotlib.pyplot as plt
import yaml

# %%
# torontoData = "..\\data\\Export_TorontoData.json"

# %%
# with open(torontoData,'r') as f:
#         data = f.readlines()
#         data = list(map(json.loads, data))

# %%
# data= data[0]
# df = pd.DataFrame(data)

# %%
# pd.set_option('display.max_columns', None)
# df.head(7)

# %%
businessDF = pd.read_csv("..\\data\\businesses_final_toronto.csv")

# %%
businessDF
# Out:
#        Unnamed: 0                                          alias  \
# 0               0                          the-ossington-toronto
# 1               1                        life-is-sweet-toronto-3
# 2               2                              subway-toronto-51
# 3               3           quest-health-and-performance-toronto
# 4               4                    locksmith-vaughan-vaughan-3
# 5               5                      jodies-restaurant-toronto
# 6               6         manuel-torres-tutor-de-español-toronto
# 7               7                            hospitals-toronto-3
# 8               8               downsview-chiropractic-toronto-2
# 9               9           sheffield-moving-and-storage-toronto
# 10             10                    gb-autos-and-trucks-toronto
# 11             11           the-great-canadian-bagel-ltd-vaughan
# 12             12                        alligator-party-toronto
# ...

# %%
coordinateDictionary ={'latitude':[], 'longitude':[]} 

for coordinate in df['coordinates']:
    coordinateDict = yaml.load(coordinate)
    coordinateDictionary['latitude'].append(coordinateDict['latitude'])
    coordinateDictionary['longitude'].append(coordinateDict['longitude'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   after removing the cwd from sys.path.

# %%
coordinateDictionary
# Out:
# {'latitude': [43.66205,
#   43.66205,
#   43.66205,
#   43.7495489,
#   43.7495489,
#   43.66528,
#   43.8258200636421,
#   43.8258200636421,
#   43.8258200636421,
#   43.8258200636421,
#   43.8258200636421,
#   43.8258200636421,
#   43.8258200636421,
#   43.8258200636421,
#   43.8258200636421,
#   43.8258200636421,
#   43.8258200636421,
#   43.8258200636421,
#   43.8258200636421,
#   43.8258200636421,
#   43.8258200636421,
#   43.8258200636421,
#   43.8258200636421,
#   43.8258200636421,
#   43.8258200636421,
#   43.8258200636421,
#   43.8258200636421,
#   43.8258200636421,
#   43.8258200636421,
#   43.8258200636421,
#   43.8258200636421,
#   43.8258200636421,
#   43.8258200636421,
#   43.8258200636421,
#   43.8258200636421,
#   43.8258200636421,
#   43.8258200636421,
#   43.8258200636421,
#   43.78268,
#   43.78268,
#   43.78268,
#   43.78268,
#   43.78268,
#   43.78268,
#   43.78268,
#   44.1501922607422,
#   43.8444616835666,
#   43.8444616835666,
#   43.8444616835666,
# ...

# %%
coordinateDF = pd.DataFrame(data, columns = ['latitude', 'longitude'])
# Out:
# dict

# %%
listd = []
listd.append(43.255)

# %%
listd
# Out:
# [43.255]

# %%
coordinateDictionary['latitude'].append(1)

# %%
pd.DataFrame(list(df['coordinates'].items()))
# Out:
#              0                                                  1
# 0            0     {'latitude': 43.66205, 'longitude': -79.38597}
# 1            1     {'latitude': 43.66205, 'longitude': -79.38597}
# 2            2     {'latitude': 43.66205, 'longitude': -79.38597}
# 3            3  {'latitude': 43.7495489, 'longitude': -79.5807...
# 4            4  {'latitude': 43.7495489, 'longitude': -79.5807...
# 5            5     {'latitude': 43.66528, 'longitude': -79.40358}
# 6            6  {'latitude': 43.8258200636421, 'longitude': -7...
# 7            7  {'latitude': 43.8258200636421, 'longitude': -7...
# 8            8  {'latitude': 43.8258200636421, 'longitude': -7...
# 9            9  {'latitude': 43.8258200636421, 'longitude': -7...
# 10          10  {'latitude': 43.8258200636421, 'longitude': -7...
# 11          11  {'latitude': 43.8258200636421, 'longitude': -7...
# 12          12  {'latitude': 43.8258200636421, 'longitude': -7...
# ...

# %%
df.plot(kind="scatter", x="longitude", y="latitude", alpha=0.4)
plt.show()
